# %%
# !git clone https://github.com/ABaldrati/CLIP4Cir
# Out:
# Cloning into 'CLIP4Cir'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 53 (delta 14), reused 6 (delta 6), pack-reused 31 (from 1)
# Receiving objects: 100% (53/53), 1.52 MiB | 11.79 MiB/s, done.
# Resolving deltas: 100% (18/18), done.

# %%
# !pip install comet-ml==3.21.0
# !pip install git+https://github.com/openai/CLIP.git
# !pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 -f 'https://download.pytorch.org/whl/torch_stable.html'
# !pip install pandas==1.4.2
# !pip install urllib3==1.26.15
# !pip install -U comet-ml
# Out:
# Collecting comet-ml==3.21.0
#   Downloading comet_ml-3.21.0-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: websocket-client>=0.55.0 in /usr/local/lib/python3.10/dist-packages (from comet-ml==3.21.0) (1.8.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from comet-ml==3.21.0) (2.32.3)
# Collecting requests-toolbelt>=0.8.0 (from comet-ml==3.21.0)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from comet-ml==3.21.0) (1.16.0)
# Requirement already satisfied: wurlitzer>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from comet-ml==3.21.0) (3.1.1)
# Collecting nvidia-ml-py3>=7.352.0 (from comet-ml==3.21.0)
#   Downloading nvidia-ml-py3-7.352.0.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from comet-ml==3.21.0) (4.23.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.10/dist-packages (from comet-ml==3.21.0) (1.16.0)
# Collecting semantic-version>=2.8.0 (from comet-ml==3.21.0)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting everett>=1.0.1 (from everett[ini]>=1.0.1; python_version > "3.5"->comet-ml==3.21.0)
#   Downloading everett-3.4.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting dulwich>=0.20.6 (from comet-ml==3.21.0)
#   Downloading dulwich-0.22.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.10/dist-packages (from dulwich>=0.20.6->comet-ml==3.21.0) (2.2.3)
# Collecting configobj (from everett[ini]>=1.0.1; python_version > "3.5"->comet-ml==3.21.0)
#   Downloading configobj-5.0.9-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml==3.21.0) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml==3.21.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml==3.21.0) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml==3.21.0) (0.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet-ml==3.21.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet-ml==3.21.0) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet-ml==3.21.0) (2024.8.30)
# Downloading comet_ml-3.21.0-py2.py3-none-any.whl (304 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.9/304.9 kB 6.9 MB/s eta 0:00:00ta 0:00:01
# Downloading dulwich-0.22.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (980 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 980.3/980.3 kB 32.7 MB/s eta 0:00:00
# Downloading everett-3.4.0-py3-none-any.whl (34 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.2 MB/s eta 0:00:00
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading configobj-5.0.9-py2.py3-none-any.whl (35 kB)
# Building wheels for collected packages: nvidia-ml-py3
#   Building wheel for nvidia-ml-py3 (setup.py) ... done
#   Created wheel for nvidia-ml-py3: filename=nvidia_ml_py3-7.352.0-py3-none-any.whl size=19171 sha256=66fb0a372174629ccf71487765fcac7bce15dbfca78e0b77b8d98b1f34f2b785
#   Stored in directory: /root/.cache/pip/wheels/5c/d8/c0/46899f8be7a75a2ffd197a23c8797700ea858b9b34819fbf9e
# Successfully built nvidia-ml-py3
# Installing collected packages: nvidia-ml-py3, semantic-version, everett, dulwich, configobj, requests-toolbelt, comet-ml
# Successfully installed comet-ml-3.21.0 configobj-5.0.9 dulwich-0.22.7 everett-3.4.0 nvidia-ml-py3-7.352.0 requests-toolbelt-1.0.0 semantic-version-2.10.0
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-0u9m3gr2
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-0u9m3gr2
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# Collecting ftfy (from clip==1.0)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (24.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (4.66.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (2.4.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (0.19.1+cu121)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from ftfy->clip==1.0) (0.2.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (2024.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->clip==1.0) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->clip==1.0) (1.3.0)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 1.7 MB/s eta 0:00:00
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369490 sha256=c925fd42298ff44cf2323153f66cec71bb80f00c07464c95df3a2dd36296e77c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jzr7dhhx/wheels/da/2b/4c/d6691fa9597aac8bb85d2ac13b112deb897d5b50f5ad9a37e4
# Successfully built clip
# Installing collected packages: ftfy, clip
# Successfully installed clip-1.0 ftfy-6.3.1
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.11.0+cu113
#   Downloading https://download.pytorch.org/whl/cu113/torch-1.11.0%2Bcu113-cp310-cp310-linux_x86_64.whl (1637.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 GB 700.0 kB/s eta 0:00:0000:0100:01
# Collecting torchvision==0.12.0+cu113
#   Downloading https://download.pytorch.org/whl/cu113/torchvision-0.12.0%2Bcu113-cp310-cp310-linux_x86_64.whl (22.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 4.5 MB/s eta 0:00:00:00:01m0:01m
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.11.0+cu113) (4.12.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.12.0+cu113) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.12.0+cu113) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.12.0+cu113) (10.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0+cu113) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0+cu113) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0+cu113) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0+cu113) (2024.8.30)
# Installing collected packages: torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.1+cu121
#     Uninstalling torch-2.4.1+cu121:
#       Successfully uninstalled torch-2.4.1+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.19.1+cu121
#     Uninstalling torchvision-0.19.1+cu121:
#       Successfully uninstalled torchvision-0.19.1+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytorch-lightning 2.4.0 requires torch>=2.1.0, but you have torch 1.11.0+cu113 which is incompatible.
# stable-baselines3 2.1.0 requires torch>=1.13, but you have torch 1.11.0+cu113 which is incompatible.
# torchaudio 2.4.1+cu121 requires torch==2.4.1, but you have torch 1.11.0+cu113 which is incompatible.
# torchmetrics 1.6.0 requires torch>=2.0.0, but you have torch 1.11.0+cu113 which is incompatible.
# Successfully installed torch-1.11.0+cu113 torchvision-0.12.0+cu113
# Collecting pandas==1.4.2
#   Downloading pandas-1.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas==1.4.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==1.4.2) (2024.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas==1.4.2) (1.26.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas==1.4.2) (1.16.0)
# Downloading pandas-1.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 100.1 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Uninstalling pandas-2.1.4:
#       Successfully uninstalled pandas-2.1.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# arviz 0.19.0 requires pandas>=1.5.0, but you have pandas 1.4.2 which is incompatible.
# bigframes 1.17.0 requires pandas>=1.5.3, but you have pandas 1.4.2 which is incompatible.
# cudf-cu12 24.4.1 requires pandas<2.2.2dev0,>=2.0, but you have pandas 1.4.2 which is incompatible.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 18.1.0 which is incompatible.
# dask-expr 1.1.21 requires pandas>=2, but you have pandas 1.4.2 which is incompatible.
# featuretools 1.31.0 requires pandas>=2.0.0, but you have pandas 1.4.2 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.5, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.1.4, but you have pandas 1.4.2 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 18.1.0 which is incompatible.
# mizani 0.11.4 requires pandas>=2.1.0, but you have pandas 1.4.2 which is incompatible.
# pandas-gbq 0.23.1 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# plotnine 0.13.6 requires pandas<3.0.0,>=2.1.0, but you have pandas 1.4.2 which is incompatible.
# pyldavis 3.4.1 requires pandas>=2.0.0, but you have pandas 1.4.2 which is incompatible.
# stable-baselines3 2.1.0 requires torch>=1.13, but you have torch 1.11.0+cu113 which is incompatible.
# visions 0.7.6 requires pandas>=2.0.0, but you have pandas 1.4.2 which is incompatible.
# woodwork 0.31.0 requires pandas>=2.0.0, but you have pandas 1.4.2 which is incompatible.
# xarray 2024.9.0 requires pandas>=2.1, but you have pandas 1.4.2 which is incompatible.
# Successfully installed pandas-1.4.2
# Collecting urllib3==1.26.15
#   Downloading urllib3-1.26.15-py2.py3-none-any.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 1.8 MB/s eta 0:00:00
# Downloading urllib3-1.26.15-py2.py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.9/140.9 kB 5.4 MB/s eta 0:00:00
# Installing collected packages: urllib3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.3
#     Uninstalling urllib3-2.2.3:
#       Successfully uninstalled urllib3-2.2.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# distributed 2024.8.0 requires dask==2024.8.0, but you have dask 2024.12.1 which is incompatible.
# Successfully installed urllib3-1.26.15
# Requirement already satisfied: comet-ml in /usr/local/lib/python3.10/dist-packages (3.21.0)
# Collecting comet-ml
#   Downloading comet_ml-3.47.6-py3-none-any.whl.metadata (3.9 kB)
# Collecting everett<3.2.0,>=1.0.1 (from everett[ini]<3.2.0,>=1.0.1->comet-ml)
#   Downloading everett-3.1.0-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (4.23.0)
# Requirement already satisfied: psutil>=5.6.3 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (5.9.5)
# Collecting python-box<7.0.0 (from comet-ml)
#   Downloading python_box-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.8 kB)
# Requirement already satisfied: requests-toolbelt>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (1.0.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (2.32.3)
# Requirement already satisfied: semantic-version>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (2.10.0)
# Requirement already satisfied: sentry-sdk>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (2.19.2)
# Collecting simplejson (from comet-ml)
#   Downloading simplejson-3.19.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (1.26.15)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (1.16.0)
# Requirement already satisfied: wurlitzer>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (3.1.1)
# Requirement already satisfied: dulwich!=0.20.33,>=0.20.6 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (0.22.7)
# Requirement already satisfied: rich>=13.3.2 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (13.8.1)
# Requirement already satisfied: configobj in /usr/local/lib/python3.10/dist-packages (from everett[ini]<3.2.0,>=1.0.1->comet-ml) (5.0.9)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml) (0.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet-ml) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet-ml) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet-ml) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet-ml) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet-ml) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=13.3.2->comet-ml) (0.1.2)
# Downloading comet_ml-3.47.6-py3-none-any.whl (710 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 710.6/710.6 kB 11.8 MB/s eta 0:00:00a 0:00:01
# Downloading everett-3.1.0-py2.py3-none-any.whl (35 kB)
# Downloading python_box-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 52.5 MB/s eta 0:00:00:00:01
# Downloading simplejson-3.19.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 9.2 MB/s eta 0:00:00
# Installing collected packages: everett, simplejson, python-box, comet-ml
#   Attempting uninstall: everett
#     Found existing installation: everett 3.4.0
#     Uninstalling everett-3.4.0:
#       Successfully uninstalled everett-3.4.0
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.2.0
#     Uninstalling python-box-7.2.0:
#       Successfully uninstalled python-box-7.2.0
#   Attempting uninstall: comet-ml
#     Found existing installation: comet-ml 3.21.0
#     Uninstalling comet-ml-3.21.0:
#       Successfully uninstalled comet-ml-3.21.0
# Successfully installed comet-ml-3.47.6 everett-3.1.0 python-box-6.1.0 simplejson-3.19.3

# %%
import shutil
import os

# Define source and destination directories
source_dir = '/kaggle/input/fashioniq2'
destination_dir = '/kaggle/working/CLIP4Cir'

# Define the specific source directories for each folder
directories_to_copy = {
    'captions': 'captions-20220326T130604Z-001',
    'image_splits': 'image_splits-20220326T130551Z-001',
    'images': 'images'
}

# Loop through each directory and copy it
for folder_name, src_subdir in directories_to_copy.items():
    src_path = os.path.join(source_dir, src_subdir)
    dest_path = os.path.join(destination_dir, folder_name)
    
    # Ensure the destination directory exists
    os.makedirs(dest_path, exist_ok=True)
    
    # Copy the directory content recursively
    shutil.copytree(src_path, dest_path, dirs_exist_ok=True)

print("Directories copied successfully.")
# Out:
# Directories copied successfully.

# %%
import os
import shutil

# Define source and destination directories
source_dir = '/kaggle/working/CLIP4Cir'
destination_dir = os.path.join(source_dir, 'fashionIQ_dataset')

# Create FashionIQ_dataset directory if it does not exist
os.makedirs(destination_dir, exist_ok=True)

# Define the directories to move
directories_to_move = {
    'captions/captions': 'captions',
    'image_splits/image_splits': 'image_splits',
    'images/images': 'images'
}

# Loop through each directory and check if it exists before moving
for src_subdir, dest_subdir in directories_to_move.items():
    src_path = os.path.join(source_dir, src_subdir)
    dest_path = os.path.join(destination_dir, dest_subdir)
    
    # Check if the source directory exists
    if os.path.exists(src_path):
        # Move the directory to the new location
        shutil.move(src_path, dest_path)
        print(f"Moved {src_path} to {dest_path}")
    else:
        print(f"Source directory {src_path} does not exist.")

print("Directories moved successfully.")
# Out:
# Moved /kaggle/working/CLIP4Cir/captions/captions to /kaggle/working/CLIP4Cir/fashionIQ_dataset/captions
# Moved /kaggle/working/CLIP4Cir/image_splits/image_splits to /kaggle/working/CLIP4Cir/fashionIQ_dataset/image_splits
# Moved /kaggle/working/CLIP4Cir/images/images to /kaggle/working/CLIP4Cir/fashionIQ_dataset/images
# Directories moved successfully.

# %%
from PIL import Image
import os

# Define the directory containing the images
images_dir = '/kaggle/working/CLIP4Cir/fashionIQ_dataset/images'

# Loop through all files in the directory
for filename in os.listdir(images_dir):
    if filename.endswith('.png'):  # Check if the file is a PNG image
        png_path = os.path.join(images_dir, filename)
        
        # Open the PNG image
        with Image.open(png_path) as img:
            # Convert the image to RGB (required for saving as JPG)
            rgb_img = img.convert('RGB')
            
            # Define the new file path with JPG extension
            jpg_path = os.path.join(images_dir, filename.replace('.png', '.jpg'))
            
            # Save the image as JPG
            rgb_img.save(jpg_path, 'JPEG')

            # Optionally, delete the original PNG file
            os.remove(png_path)

print("PNG files have been successfully converted to JPG.")
# Out:
# PNG files have been successfully converted to JPG.

# %%
import torch
torch.cuda.empty_cache()

# %%
# !python /kaggle/working/CLIP4Cir/src/clip_fine_tune.py \
   --dataset FashionIQ \
   --api-key bKMwHTWGZ1fqpCdlAWHrPrP1M \
   --workspace longnguyenha050 \
   --experiment-name clip-finetune-fashioniq \
   --num-epochs 100 \
   --clip-model-name RN50x4 \
   --encoder both \
   --learning-rate 2e-6 \
   --batch-size 32 \
   --transform targetpad \
   --target-ratio 1.25  \
   --save-training \
   --save-best \
   --validation-frequency 1
# Out:
# Comet logging ENABLED
# COMET INFO: Experiment is live on comet.com https://www.comet.com/longnguyenha050/fashioniq-clip-fine-tuning/224c67b453434eaba386c59143128f19
#
# COMET INFO: Couldn't find a Git repository in '/kaggle/working' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# 100%|███████████████████████████████████████| 402M/402M [00:05<00:00, 84.1MiB/s]
# Both CLIP encoders will be fine-tuned
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/transforms.py:332: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(
# Target pad with target_ratio = 1.25 preprocess pipeline is used
# FashionIQ val - ['dress'] dataset in relative mode initialized
# FashionIQ val - ['dress'] dataset in classic mode initialized
# FashionIQ val - ['toptee'] dataset in relative mode initialized
# FashionIQ val - ['toptee'] dataset in classic mode initialized
# FashionIQ val - ['shirt'] dataset in relative mode initialized
# FashionIQ val - ['shirt'] dataset in classic mode initialized
# FashionIQ train - ['dress', 'toptee', 'shirt'] dataset in relative mode initialized
# Training loop started
# [0/100] train loss: 0.850 : 100%|███████████████████████████████████████████████████████████████████████████████████| 562/562 [13:03<00:00,  1.39s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:57<00:00,  2.10it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.90it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:19<00:00,  2.11it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.75it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:35<00:00,  2.09it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.85it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 31.581556797027588,
#     "dress_recall_at50": 56.61873817443848,
#     "toptee_recall_at10": 40.64252972602844,
#     "toptee_recall_at50": 63.74298930168152,
#     "shirt_recall_at10": 38.370952010154724,
#     "shirt_recall_at50": 59.66634154319763,
#     "average_recall_at10": 36.86501284440359,
#     "average_recall_at50": 60.009356339772545,
#     "average_recall": 48.437184592088066
# }
# [1/100] train loss: 0.639 : 100%|███████████████████████████████████████████████████████████████████████████████████| 562/562 [13:12<00:00,  1.41s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.11it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.96it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:19<00:00,  2.10it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.68it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:35<00:00,  2.09it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.84it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 34.060487151145935,
#     "dress_recall_at50": 59.295982122421265,
#     "toptee_recall_at10": 42.17236042022705,
#     "toptee_recall_at50": 66.03773832321167,
#     "shirt_recall_at10": 39.842984080314636,
#     "shirt_recall_at50": 61.33463978767395,
#     "average_recall_at10": 38.691943883895874,
#     "average_recall_at50": 62.22278674443563,
#     "average_recall": 50.457365314165756
# }
# [2/100] train loss: 0.546 : 100%|███████████████████████████████████████████████████████████████████████████████████| 562/562 [13:11<00:00,  1.41s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.13it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.97it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:19<00:00,  2.11it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.67it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:35<00:00,  2.08it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.84it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 34.010908007621765,
#     "dress_recall_at50": 60.58502793312073,
#     "toptee_recall_at10": 43.039265275001526,
#     "toptee_recall_at50": 66.95563197135925,
#     "shirt_recall_at10": 39.54857587814331,
#     "shirt_recall_at50": 62.31599450111389,
#     "average_recall_at10": 38.86624972025553,
#     "average_recall_at50": 63.28555146853129,
#     "average_recall": 51.07590059439341
# }
# [3/100] train loss: 0.482 : 100%|███████████████████████████████████████████████████████████████████████████████████| 562/562 [13:11<00:00,  1.41s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.11it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.89it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:19<00:00,  2.11it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.73it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:35<00:00,  2.09it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.82it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 34.159642457962036,
#     "dress_recall_at50": 58.94893407821655,
#     "toptee_recall_at10": 43.498215079307556,
#     "toptee_recall_at50": 66.29270911216736,
#     "shirt_recall_at10": 39.54857587814331,
#     "shirt_recall_at50": 62.11972236633301,
#     "average_recall_at10": 39.06881113847097,
#     "average_recall_at50": 62.45378851890564,
#     "average_recall": 50.76129982868831
# }
# [4/100] train loss: 0.435 : 100%|███████████████████████████████████████████████████████████████████████████████████| 562/562 [13:12<00:00,  1.41s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.12it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.91it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:20<00:00,  2.09it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.65it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:34<00:00,  2.10it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.83it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 34.50669348239899,
#     "dress_recall_at50": 61.03123426437378,
#     "toptee_recall_at10": 44.4671094417572,
#     "toptee_recall_at50": 68.02651882171631,
#     "shirt_recall_at10": 39.20510411262512,
#     "shirt_recall_at50": 62.512266635894775,
#     "average_recall_at10": 39.39296901226044,
#     "average_recall_at50": 63.85667324066162,
#     "average_recall": 51.62482112646103
# }
# [5/100] train loss: 0.383 : 100%|███████████████████████████████████████████████████████████████████████████████████| 562/562 [13:12<00:00,  1.41s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.12it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.93it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:20<00:00,  2.10it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.64it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:35<00:00,  2.08it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.80it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 34.308379888534546,
#     "dress_recall_at50": 61.13039255142212,
#     "toptee_recall_at10": 43.80418062210083,
#     "toptee_recall_at50": 67.00662970542908,
#     "shirt_recall_at10": 39.94112014770508,
#     "shirt_recall_at50": 62.41413354873657,
#     "average_recall_at10": 39.35122688611349,
#     "average_recall_at50": 63.51705193519592,
#     "average_recall": 51.43413941065471
# }
# [6/100] train loss: 0.340 : 100%|███████████████████████████████████████████████████████████████████████████████████| 562/562 [13:11<00:00,  1.41s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.12it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  7.03it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:19<00:00,  2.10it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.65it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:35<00:00,  2.08it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.82it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 34.80416536331177,
#     "dress_recall_at50": 60.98165512084961,
#     "toptee_recall_at10": 43.29423904418945,
#     "toptee_recall_at50": 66.80265069007874,
#     "shirt_recall_at10": 39.45044279098511,
#     "shirt_recall_at50": 62.75760531425476,
#     "average_recall_at10": 39.18294906616211,
#     "average_recall_at50": 63.513970375061035,
#     "average_recall": 51.34845972061157
# }
# [7/100] train loss: 0.319 : 100%|███████████████████████████████████████████████████████████████████████████████████| 562/562 [13:11<00:00,  1.41s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.11it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.90it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:19<00:00,  2.11it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.72it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:35<00:00,  2.09it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.81it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 33.862170577049255,
#     "dress_recall_at50": 60.33713221549988,
#     "toptee_recall_at10": 43.7021940946579,
#     "toptee_recall_at50": 67.7205502986908,
#     "shirt_recall_at10": 40.48086404800415,
#     "shirt_recall_at50": 62.61039972305298,
#     "average_recall_at10": 39.3484095732371,
#     "average_recall_at50": 63.55602741241455,
#     "average_recall": 51.45221849282582
# }
# [8/100] train loss: 0.291 : 100%|███████████████████████████████████████████████████████████████████████████████████| 562/562 [13:09<00:00,  1.41s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.13it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.92it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:20<00:00,  2.09it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.63it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:34<00:00,  2.11it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.88it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 34.159642457962036,
#     "dress_recall_at50": 59.940505027770996,
#     "toptee_recall_at10": 41.40744507312775,
#     "toptee_recall_at50": 65.47679901123047,
#     "shirt_recall_at10": 38.27281594276428,
#     "shirt_recall_at50": 61.28557324409485,
#     "average_recall_at10": 37.94663449128469,
#     "average_recall_at50": 62.23429242769877,
#     "average_recall": 50.09046345949173
# }
# [9/100] train loss: 0.274 : 100%|███████████████████████████████████████████████████████████████████████████████████| 562/562 [13:10<00:00,  1.41s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.12it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.92it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:20<00:00,  2.09it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.67it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:35<00:00,  2.09it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.83it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 34.159642457962036,
#     "dress_recall_at50": 60.089242458343506,
#     "toptee_recall_at10": 42.27434992790222,
#     "toptee_recall_at50": 66.70066118240356,
#     "shirt_recall_at10": 40.628066658973694,
#     "shirt_recall_at50": 61.72718405723572,
#     "average_recall_at10": 39.02068634827932,
#     "average_recall_at50": 62.83902923266093,
#     "average_recall": 50.92985779047012
# }
# [10/100] train loss: 0.246 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:10<00:00,  1.41s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.12it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.93it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:19<00:00,  2.11it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.68it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:35<00:00,  2.08it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.78it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 34.65542793273926,
#     "dress_recall_at50": 60.53544878959656,
#     "toptee_recall_at10": 42.121365666389465,
#     "toptee_recall_at50": 66.80265069007874,
#     "shirt_recall_at10": 40.38272798061371,
#     "shirt_recall_at50": 63.10107707977295,
#     "average_recall_at10": 39.053173859914146,
#     "average_recall_at50": 63.47972551981608,
#     "average_recall": 51.26644968986511
# }
# [11/100] train loss: 0.223 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:09<00:00,  1.41s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.13it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.96it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:20<00:00,  2.10it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.63it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:34<00:00,  2.11it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.86it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 33.763015270233154,
#     "dress_recall_at50": 60.98165512084961,
#     "toptee_recall_at10": 40.9994900226593,
#     "toptee_recall_at50": 65.68077802658081,
#     "shirt_recall_at10": 39.254170656204224,
#     "shirt_recall_at50": 62.31599450111389,
#     "average_recall_at10": 38.00555864969889,
#     "average_recall_at50": 62.992809216181435,
#     "average_recall": 50.49918393294016
# }
# [12/100] train loss: 0.211 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:10<00:00,  1.41s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.11it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.88it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:20<00:00,  2.10it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.69it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:35<00:00,  2.09it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.84it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 34.50669348239899,
#     "dress_recall_at50": 60.73376536369324,
#     "toptee_recall_at10": 42.78429448604584,
#     "toptee_recall_at50": 66.13972187042236,
#     "shirt_recall_at10": 40.38272798061371,
#     "shirt_recall_at50": 62.61039972305298,
#     "average_recall_at10": 39.22457198301951,
#     "average_recall_at50": 63.161295652389526,
#     "average_recall": 51.192933817704514
# }
# [13/100] train loss: 0.194 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:09<00:00,  1.41s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.11it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.88it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:19<00:00,  2.11it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.67it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:35<00:00,  2.08it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.82it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 34.060487151145935,
#     "dress_recall_at50": 59.14725065231323,
#     "toptee_recall_at10": 42.01937913894653,
#     "toptee_recall_at50": 65.11983871459961,
#     "shirt_recall_at10": 39.254170656204224,
#     "shirt_recall_at50": 62.070655822753906,
#     "average_recall_at10": 38.4446789820989,
#     "average_recall_at50": 62.112581729888916,
#     "average_recall": 50.27863035599391
# }
# [14/100] train loss: 0.189 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:08<00:00,  1.40s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.11it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.91it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:19<00:00,  2.11it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.72it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:35<00:00,  2.09it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.80it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 33.663856983184814,
#     "dress_recall_at50": 60.237979888916016,
#     "toptee_recall_at10": 40.846505761146545,
#     "toptee_recall_at50": 65.32381176948547,
#     "shirt_recall_at10": 39.05789852142334,
#     "shirt_recall_at50": 63.19921612739563,
#     "average_recall_at10": 37.8560870885849,
#     "average_recall_at50": 62.92033592859904,
#     "average_recall": 50.388211508591965
# }
# [15/100] train loss: 0.177 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:09<00:00,  1.40s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.13it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.93it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:19<00:00,  2.10it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.64it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:34<00:00,  2.10it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.83it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 33.812594413757324,
#     "dress_recall_at50": 61.08081340789795,
#     "toptee_recall_at10": 41.25446081161499,
#     "toptee_recall_at50": 65.47679901123047,
#     "shirt_recall_at10": 38.71442675590515,
#     "shirt_recall_at50": 61.38371229171753,
#     "average_recall_at10": 37.92716066042582,
#     "average_recall_at50": 62.64710823694865,
#     "average_recall": 50.28713444868723
# }
# [16/100] train loss: 0.169 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:10<00:00,  1.41s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.13it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.91it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:20<00:00,  2.10it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.60it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:34<00:00,  2.10it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.83it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 34.95289981365204,
#     "dress_recall_at50": 59.345561265945435,
#     "toptee_recall_at10": 42.07037091255188,
#     "toptee_recall_at50": 66.70066118240356,
#     "shirt_recall_at10": 38.861629366874695,
#     "shirt_recall_at50": 62.31599450111389,
#     "average_recall_at10": 38.62830003102621,
#     "average_recall_at50": 62.78740564982096,
#     "average_recall": 50.707852840423584
# }
# [17/100] train loss: 0.159 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:11<00:00,  1.41s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.11it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.85it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:19<00:00,  2.11it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.73it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:35<00:00,  2.09it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.81it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 33.812594413757324,
#     "dress_recall_at50": 59.09767150878906,
#     "toptee_recall_at10": 41.96838438510895,
#     "toptee_recall_at50": 65.88475108146667,
#     "shirt_recall_at10": 38.56722414493561,
#     "shirt_recall_at50": 61.530911922454834,
#     "average_recall_at10": 38.11606764793396,
#     "average_recall_at50": 62.171111504236855,
#     "average_recall": 50.143589576085404
# }
# [18/100] train loss: 0.147 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:11<00:00,  1.41s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.12it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.92it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:19<00:00,  2.11it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.65it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:35<00:00,  2.09it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.83it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 34.60584878921509,
#     "dress_recall_at50": 60.43629050254822,
#     "toptee_recall_at10": 41.203469038009644,
#     "toptee_recall_at50": 65.62978029251099,
#     "shirt_recall_at10": 39.94112014770508,
#     "shirt_recall_at50": 60.94210147857666,
#     "average_recall_at10": 38.5834793249766,
#     "average_recall_at50": 62.33605742454529,
#     "average_recall": 50.45976837476094
# }
# [19/100] train loss: 0.143 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:09<00:00,  1.40s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.12it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.90it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:20<00:00,  2.10it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.63it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:34<00:00,  2.10it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.76it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 34.159642457962036,
#     "dress_recall_at50": 59.444719552993774,
#     "toptee_recall_at10": 41.15247428417206,
#     "toptee_recall_at50": 65.32381176948547,
#     "shirt_recall_at10": 39.793914556503296,
#     "shirt_recall_at50": 61.87438368797302,
#     "average_recall_at10": 38.3686770995458,
#     "average_recall_at50": 62.21430500348409,
#     "average_recall": 50.291491051514946
# }
# [20/100] train loss: 0.143 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:09<00:00,  1.40s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.12it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.90it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:20<00:00,  2.09it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.64it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:34<00:00,  2.10it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.82it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 33.415964245796204,
#     "dress_recall_at50": 59.14725065231323,
#     "toptee_recall_at10": 42.17236042022705,
#     "toptee_recall_at50": 65.32381176948547,
#     "shirt_recall_at10": 39.254170656204224,
#     "shirt_recall_at50": 61.43277883529663,
#     "average_recall_at10": 38.28083177407583,
#     "average_recall_at50": 61.96794708569845,
#     "average_recall": 50.12438942988714
# }
# [21/100] train loss: 0.130 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:09<00:00,  1.40s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.11it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.94it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:20<00:00,  2.09it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.63it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:34<00:00,  2.10it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.83it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 33.21765065193176,
#     "dress_recall_at50": 59.742188453674316,
#     "toptee_recall_at10": 41.35645031929016,
#     "toptee_recall_at50": 66.29270911216736,
#     "shirt_recall_at10": 39.45044279098511,
#     "shirt_recall_at50": 60.99116802215576,
#     "average_recall_at10": 38.00818125406901,
#     "average_recall_at50": 62.34202186266581,
#     "average_recall": 50.17510155836741
# }
# [22/100] train loss: 0.125 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:08<00:00,  1.40s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.11it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.88it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:19<00:00,  2.11it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.73it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:34<00:00,  2.10it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.99it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 31.680715084075928,
#     "dress_recall_at50": 58.55230689048767,
#     "toptee_recall_at10": 41.10147953033447,
#     "toptee_recall_at50": 66.24171137809753,
#     "shirt_recall_at10": 39.20510411262512,
#     "shirt_recall_at50": 60.84396243095398,
#     "average_recall_at10": 37.329099575678505,
#     "average_recall_at50": 61.8793268998464,
#     "average_recall": 49.60421323776245
# }
# [23/100] train loss: 0.124 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:08<00:00,  1.40s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.13it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.95it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:19<00:00,  2.11it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.66it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:35<00:00,  2.09it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.79it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 33.06891322135925,
#     "dress_recall_at50": 58.99851322174072,
#     "toptee_recall_at10": 41.10147953033447,
#     "toptee_recall_at50": 65.11983871459961,
#     "shirt_recall_at10": 37.83120810985565,
#     "shirt_recall_at50": 61.187440156936646,
#     "average_recall_at10": 37.33386695384979,
#     "average_recall_at50": 61.76859736442566,
#     "average_recall": 49.551232159137726
# }
# [24/100] train loss: 0.125 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:07<00:00,  1.40s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.12it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.91it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:20<00:00,  2.09it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.61it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:34<00:00,  2.11it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.85it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 31.383243203163147,
#     "dress_recall_at50": 57.65988826751709,
#     "toptee_recall_at10": 39.82661962509155,
#     "toptee_recall_at50": 63.895970582962036,
#     "shirt_recall_at10": 38.0274772644043,
#     "shirt_recall_at50": 59.96074676513672,
#     "average_recall_at10": 36.412446697553,
#     "average_recall_at50": 60.505535205205284,
#     "average_recall": 48.45899095137914
# }
# [25/100] train loss: 0.112 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:06<00:00,  1.40s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.11it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.88it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:19<00:00,  2.11it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.71it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:35<00:00,  2.09it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.87it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 31.8294495344162,
#     "dress_recall_at50": 58.45314860343933,
#     "toptee_recall_at10": 40.387555956840515,
#     "toptee_recall_at50": 63.99796009063721,
#     "shirt_recall_at10": 37.63493597507477,
#     "shirt_recall_at50": 60.94210147857666,
#     "average_recall_at10": 36.617313822110496,
#     "average_recall_at50": 61.131070057551064,
#     "average_recall": 48.87419193983078
# }
# [26/100] train loss: 0.100 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:06<00:00,  1.40s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.12it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.92it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:20<00:00,  2.09it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.64it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:34<00:00,  2.10it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.80it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 32.82102048397064,
#     "dress_recall_at50": 58.35399031639099,
#     "toptee_recall_at10": 41.81540012359619,
#     "toptee_recall_at50": 66.08873009681702,
#     "shirt_recall_at10": 39.64671194553375,
#     "shirt_recall_at50": 60.79489588737488,
#     "average_recall_at10": 38.094377517700195,
#     "average_recall_at50": 61.7458721001943,
#     "average_recall": 49.92012480894725
# }
# [27/100] train loss: 0.101 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:06<00:00,  1.40s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.13it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.90it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:19<00:00,  2.10it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.63it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:35<00:00,  2.09it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.87it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 32.96975791454315,
#     "dress_recall_at50": 59.593456983566284,
#     "toptee_recall_at10": 40.69352447986603,
#     "toptee_recall_at50": 63.64099979400635,
#     "shirt_recall_at10": 38.0274772644043,
#     "shirt_recall_at50": 59.17566418647766,
#     "average_recall_at10": 37.23025321960449,
#     "average_recall_at50": 60.80337365468343,
#     "average_recall": 49.016813437143966
# }
# [28/100] train loss: 0.108 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:07<00:00,  1.40s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.11it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.90it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:19<00:00,  2.11it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.70it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:35<00:00,  2.09it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.82it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 33.763015270233154,
#     "dress_recall_at50": 58.7010383605957,
#     "toptee_recall_at10": 41.45843982696533,
#     "toptee_recall_at50": 64.91585969924927,
#     "shirt_recall_at10": 37.73307204246521,
#     "shirt_recall_at50": 60.00981330871582,
#     "average_recall_at10": 37.651509046554565,
#     "average_recall_at50": 61.208903789520264,
#     "average_recall": 49.430206418037415
# }
# [29/100] train loss: 0.094 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:06<00:00,  1.40s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.11it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.81it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:19<00:00,  2.11it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.67it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:35<00:00,  2.09it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.85it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 32.22607970237732,
#     "dress_recall_at50": 58.30441117286682,
#     "toptee_recall_at10": 40.9994900226593,
#     "toptee_recall_at50": 65.27281999588013,
#     "shirt_recall_at10": 37.38959729671478,
#     "shirt_recall_at50": 59.322863817214966,
#     "average_recall_at10": 36.8717223405838,
#     "average_recall_at50": 60.96669832865397,
#     "average_recall": 48.91921033461888
# }
# [30/100] train loss: 0.094 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:07<00:00,  1.40s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.12it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.87it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:19<00:00,  2.11it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.69it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:35<00:00,  2.08it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.82it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 31.8294495344162,
#     "dress_recall_at50": 58.10610055923462,
#     "toptee_recall_at10": 40.13258516788483,
#     "toptee_recall_at50": 64.35492038726807,
#     "shirt_recall_at10": 37.58586943149567,
#     "shirt_recall_at50": 60.00981330871582,
#     "average_recall_at10": 36.5159680445989,
#     "average_recall_at50": 60.823611418406166,
#     "average_recall": 48.66978973150253
# }
# [31/100] train loss: 0.092 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:07<00:00,  1.40s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.12it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.92it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:20<00:00,  2.09it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.65it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:35<00:00,  2.08it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.88it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 32.02776312828064,
#     "dress_recall_at50": 57.1145236492157,
#     "toptee_recall_at10": 38.755735754966736,
#     "toptee_recall_at50": 64.35492038726807,
#     "shirt_recall_at10": 37.68400251865387,
#     "shirt_recall_at50": 59.56820249557495,
#     "average_recall_at10": 36.15583380063375,
#     "average_recall_at50": 60.345882177352905,
#     "average_recall": 48.25085798899333
# }
# [32/100] train loss: 0.089 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:07<00:00,  1.40s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.11it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.87it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:19<00:00,  2.11it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.71it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:34<00:00,  2.10it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.89it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 31.284084916114807,
#     "dress_recall_at50": 56.767475605010986,
#     "toptee_recall_at10": 39.82661962509155,
#     "toptee_recall_at50": 63.0290687084198,
#     "shirt_recall_at10": 37.63493597507477,
#     "shirt_recall_at50": 60.00981330871582,
#     "average_recall_at10": 36.248546838760376,
#     "average_recall_at50": 59.93545254071554,
#     "average_recall": 48.09199968973796
# }
# [33/100] train loss: 0.089 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:07<00:00,  1.40s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.12it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.89it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:19<00:00,  2.11it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.71it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:34<00:00,  2.10it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.83it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 31.87902867794037,
#     "dress_recall_at50": 57.064950466156006,
#     "toptee_recall_at10": 39.77562487125397,
#     "toptee_recall_at50": 65.01784920692444,
#     "shirt_recall_at10": 38.27281594276428,
#     "shirt_recall_at50": 59.42100286483765,
#     "average_recall_at10": 36.64248983065287,
#     "average_recall_at50": 60.501267512639366,
#     "average_recall": 48.57187867164612
# }
# [34/100] train loss: 0.084 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:07<00:00,  1.40s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.12it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.92it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:19<00:00,  2.11it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.66it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:35<00:00,  2.09it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.80it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 30.937033891677856,
#     "dress_recall_at50": 56.073373556137085,
#     "toptee_recall_at10": 39.77562487125397,
#     "toptee_recall_at50": 64.66088891029358,
#     "shirt_recall_at10": 38.420018553733826,
#     "shirt_recall_at50": 59.91168022155762,
#     "average_recall_at10": 36.377559105555214,
#     "average_recall_at50": 60.21531422932943,
#     "average_recall": 48.29643666744232
# }
# [35/100] train loss: 0.087 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:06<00:00,  1.40s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.12it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.86it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:19<00:00,  2.11it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.68it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:35<00:00,  2.08it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.79it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 31.432822346687317,
#     "dress_recall_at50": 55.97422122955322,
#     "toptee_recall_at10": 39.26568031311035,
#     "toptee_recall_at50": 64.09994959831238,
#     "shirt_recall_at10": 39.05789852142334,
#     "shirt_recall_at50": 59.764474630355835,
#     "average_recall_at10": 36.585467060407005,
#     "average_recall_at50": 59.94621515274048,
#     "average_recall": 48.265841106573745
# }
# [36/100] train loss: 0.082 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:07<00:00,  1.40s/it]
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:56<00:00,  2.12it/s]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.84it/s]
# Compute FashionIQ ['dress'] validation metrics
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [01:19<00:00,  2.11it/s]
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:09<00:00,  6.71it/s]
# Compute FashionIQ ['toptee'] validation metrics
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [01:35<00:00,  2.09it/s]
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:09<00:00,  6.86it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 32.17650055885315,
#     "dress_recall_at50": 57.56073594093323,
#     "toptee_recall_at10": 39.31667506694794,
#     "toptee_recall_at50": 65.06884098052979,
#     "shirt_recall_at10": 39.05789852142334,
#     "shirt_recall_at50": 59.47006940841675,
#     "average_recall_at10": 36.850358049074806,
#     "average_recall_at50": 60.69988210995992,
#     "average_recall": 48.775120079517365
# }
# [37/100] train loss: 0.080 : 100%|██████████████████████████████████████████████████████████████████████████████████| 562/562 [13:07<00:00,  1.40s/it]
# extracting fashionIQ ['dress'] - val index features
#  46%|███████████████████▎                      | 55/120 [00:25<00:30,  2.12it/s]
