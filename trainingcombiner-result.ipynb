# %%
# !git clone https://github.com/ABaldrati/CLIP4Cir
# Out:
# fatal: destination path 'CLIP4Cir' already exists and is not an empty directory.

# %%
# !pip install comet-ml==3.21.0
# !pip install git+https://github.com/openai/CLIP.git
# !pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 -f 'https://download.pytorch.org/whl/torch_stable.html'
# !pip install pandas==1.4.2
# !pip install urllib3==1.26.15
# !pip install -U comet-ml
# Out:
# Collecting comet-ml==3.21.0
#   Using cached comet_ml-3.21.0-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: websocket-client>=0.55.0 in /usr/local/lib/python3.10/dist-packages (from comet-ml==3.21.0) (1.8.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from comet-ml==3.21.0) (2.32.3)
# Requirement already satisfied: requests-toolbelt>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from comet-ml==3.21.0) (1.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from comet-ml==3.21.0) (1.16.0)
# Requirement already satisfied: wurlitzer>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from comet-ml==3.21.0) (3.1.1)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.10/dist-packages (from comet-ml==3.21.0) (7.352.0)
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from comet-ml==3.21.0) (4.23.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.10/dist-packages (from comet-ml==3.21.0) (1.16.0)
# Requirement already satisfied: semantic-version>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from comet-ml==3.21.0) (2.10.0)
# Requirement already satisfied: everett>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from everett[ini]>=1.0.1; python_version > "3.5"->comet-ml==3.21.0) (3.1.0)
# Requirement already satisfied: dulwich>=0.20.6 in /usr/local/lib/python3.10/dist-packages (from comet-ml==3.21.0) (0.22.7)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.10/dist-packages (from dulwich>=0.20.6->comet-ml==3.21.0) (1.26.15)
# Requirement already satisfied: configobj in /usr/local/lib/python3.10/dist-packages (from everett[ini]>=1.0.1; python_version > "3.5"->comet-ml==3.21.0) (5.0.9)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml==3.21.0) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml==3.21.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml==3.21.0) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml==3.21.0) (0.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet-ml==3.21.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet-ml==3.21.0) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet-ml==3.21.0) (2024.8.30)
# Using cached comet_ml-3.21.0-py2.py3-none-any.whl (304 kB)
# Installing collected packages: comet-ml
#   Attempting uninstall: comet-ml
#     Found existing installation: comet-ml 3.47.6
#     Uninstalling comet-ml-3.47.6:
#       Successfully uninstalled comet-ml-3.47.6
# Successfully installed comet-ml-3.21.0
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-5lfk2913
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-5lfk2913
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ftfy in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (6.3.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (24.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (4.66.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (1.11.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (0.12.0+cu113)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from ftfy->clip==1.0) (0.2.13)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (4.12.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (10.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->clip==1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->clip==1.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->clip==1.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->clip==1.0) (2024.8.30)
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Requirement already satisfied: torch==1.11.0+cu113 in /usr/local/lib/python3.10/dist-packages (1.11.0+cu113)
# Requirement already satisfied: torchvision==0.12.0+cu113 in /usr/local/lib/python3.10/dist-packages (0.12.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.11.0+cu113) (4.12.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.12.0+cu113) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.12.0+cu113) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.12.0+cu113) (10.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0+cu113) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0+cu113) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0+cu113) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0+cu113) (2024.8.30)
# Requirement already satisfied: pandas==1.4.2 in /usr/local/lib/python3.10/dist-packages (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas==1.4.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==1.4.2) (2024.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas==1.4.2) (1.26.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas==1.4.2) (1.16.0)
# Requirement already satisfied: urllib3==1.26.15 in /usr/local/lib/python3.10/dist-packages (1.26.15)
# Requirement already satisfied: comet-ml in /usr/local/lib/python3.10/dist-packages (3.21.0)
# Collecting comet-ml
#   Using cached comet_ml-3.47.6-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: everett<3.2.0,>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from everett[ini]<3.2.0,>=1.0.1->comet-ml) (3.1.0)
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (4.23.0)
# Requirement already satisfied: psutil>=5.6.3 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (5.9.5)
# Requirement already satisfied: python-box<7.0.0 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (6.1.0)
# Requirement already satisfied: requests-toolbelt>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (1.0.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (2.32.3)
# Requirement already satisfied: semantic-version>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (2.10.0)
# Requirement already satisfied: sentry-sdk>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (2.19.2)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.10/dist-packages (from comet-ml) (3.19.3)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (1.26.15)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (1.16.0)
# Requirement already satisfied: wurlitzer>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (3.1.1)
# Requirement already satisfied: dulwich!=0.20.33,>=0.20.6 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (0.22.7)
# Requirement already satisfied: rich>=13.3.2 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (13.8.1)
# Requirement already satisfied: configobj in /usr/local/lib/python3.10/dist-packages (from everett[ini]<3.2.0,>=1.0.1->comet-ml) (5.0.9)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml) (0.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet-ml) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet-ml) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet-ml) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet-ml) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet-ml) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=13.3.2->comet-ml) (0.1.2)
# Using cached comet_ml-3.47.6-py3-none-any.whl (710 kB)
# Installing collected packages: comet-ml
#   Attempting uninstall: comet-ml
#     Found existing installation: comet-ml 3.21.0
#     Uninstalling comet-ml-3.21.0:
#       Successfully uninstalled comet-ml-3.21.0
# Successfully installed comet-ml-3.47.6

# %%
import shutil
import os

# Define source and destination directories
source_dir = '/kaggle/input/fashioniq2'
destination_dir = '/kaggle/working/CLIP4Cir'

# Define the specific source directories for each folder
directories_to_copy = {
    'captions': 'captions-20220326T130604Z-001',
    'image_splits': 'image_splits-20220326T130551Z-001',
    'images': 'images'
}

# Loop through each directory and copy it
for folder_name, src_subdir in directories_to_copy.items():
    src_path = os.path.join(source_dir, src_subdir)
    dest_path = os.path.join(destination_dir, folder_name)
    
    # Ensure the destination directory exists
    os.makedirs(dest_path, exist_ok=True)
    
    # Copy the directory content recursively
    shutil.copytree(src_path, dest_path, dirs_exist_ok=True)

print("Directories copied successfully.")
# Out:
# Directories copied successfully.

# %%
import os
import shutil

# Define source and destination directories
source_dir = '/kaggle/working/CLIP4Cir'
destination_dir = os.path.join(source_dir, 'fashionIQ_dataset')

# Create FashionIQ_dataset directory if it does not exist
os.makedirs(destination_dir, exist_ok=True)

# Define the directories to move
directories_to_move = {
    'captions/captions': 'captions',
    'image_splits/image_splits': 'image_splits',
    'images/images': 'images'
}

# Loop through each directory and check if it exists before moving
for src_subdir, dest_subdir in directories_to_move.items():
    src_path = os.path.join(source_dir, src_subdir)
    dest_path = os.path.join(destination_dir, dest_subdir)
    
    # Check if the source directory exists
    if os.path.exists(src_path):
        # Move the directory to the new location
        shutil.move(src_path, dest_path)
        print(f"Moved {src_path} to {dest_path}")
    else:
        print(f"Source directory {src_path} does not exist.")

print("Directories moved successfully.")
# Out:
# Moved /kaggle/working/CLIP4Cir/captions/captions to /kaggle/working/CLIP4Cir/fashionIQ_dataset/captions
# Moved /kaggle/working/CLIP4Cir/image_splits/image_splits to /kaggle/working/CLIP4Cir/fashionIQ_dataset/image_splits
# Moved /kaggle/working/CLIP4Cir/images/images to /kaggle/working/CLIP4Cir/fashionIQ_dataset/images
# Directories moved successfully.

# %%
from PIL import Image
import os

# Define the directory containing the images
images_dir = '/kaggle/working/CLIP4Cir/fashionIQ_dataset/images'

# Loop through all files in the directory
for filename in os.listdir(images_dir):
    if filename.endswith('.png'):  # Check if the file is a PNG image
        png_path = os.path.join(images_dir, filename)
        
        # Open the PNG image
        with Image.open(png_path) as img:
            # Convert the image to RGB (required for saving as JPG)
            rgb_img = img.convert('RGB')
            
            # Define the new file path with JPG extension
            jpg_path = os.path.join(images_dir, filename.replace('.png', '.jpg'))
            
            # Save the image as JPG
            rgb_img.save(jpg_path, 'JPEG')

            # Optionally, delete the original PNG file
            os.remove(png_path)

print("PNG files have been successfully converted to JPG.")
# Out:
# PNG files have been successfully converted to JPG.

# %%
import torch
torch.cuda.empty_cache()

# %%
# !python /kaggle/working/CLIP4Cir/src/combiner_train.py \
   --dataset FashionIQ \
   --api-key bKMwHTWGZ1fqpCdlAWHrPrP1M \
   --workspace longnguyenha050 \
   --experiment-name combiner_training_fashionIQ \
   --projection-dim 2560 \
   --hidden-dim 5120 \
   --num-epochs 300 \
   --clip-model-name RN50x4 \
   --clip-model-path /kaggle/input/clipfinetunepy/fiq_clip_RN50x4_fullft.pt \
   --combiner-lr 2e-5 \
   --batch-size 512 \
   --clip-bs 32 \
   --transform targetpad \
   --target-ratio 1.25 \
   --save-training \
   --save-best \
   --validation-frequency 1
# Out:
# Comet logging ENABLED
# COMET INFO: Experiment is live on comet.com https://www.comet.com/longnguyenha050/fashioniq-combiner-training/36f3c5f5ccfe40f19c82cc9c7e0430df
#
# COMET INFO: Couldn't find a Git repository in '/kaggle/working' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# /usr/local/lib/python3.10/dist-packages/clip/clip.py:57: UserWarning: /root/.cache/clip/RN50x4.pt exists, but the SHA256 checksum does not match; re-downloading the file
#   warnings.warn(f"{download_target} exists, but the SHA256 checksum does not match; re-downloading the file")
# 100%|███████████████████████████████████████| 402M/402M [00:31<00:00, 13.5MiB/s]
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/transforms.py:332: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(
# Target pad with target_ratio = 1.25 preprocess pipeline is used
# Trying to load the CLIP model
# CLIP model loaded successfully
# FashionIQ val - ['dress'] dataset in relative mode initialized
# FashionIQ val - ['dress'] dataset in classic mode initialized
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:24<00:00,  4.86it/s]
# FashionIQ val - ['toptee'] dataset in relative mode initialized
# FashionIQ val - ['toptee'] dataset in classic mode initialized
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [00:33<00:00,  4.95it/s]
# FashionIQ val - ['shirt'] dataset in relative mode initialized
# FashionIQ val - ['shirt'] dataset in classic mode initialized
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [00:39<00:00,  4.99it/s]
# FashionIQ train - ['dress', 'toptee', 'shirt'] dataset in relative mode initialized
# Training loop started
# [0/300] train loss: 1.512 : 100%|█████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:30<00:00,  7.74s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 14.32it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:04<00:00, 15.11it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.61it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 37.72930204868317,
#     "dress_recall_at50": 63.014376163482666,
#     "toptee_recall_at10": 45.43600082397461,
#     "toptee_recall_at50": 69.70933079719543,
#     "shirt_recall_at10": 42.73797869682312,
#     "shirt_recall_at50": 64.13150429725647,
#     "average_recall_at10": 41.9677605231603,
#     "average_recall_at50": 65.61840375264485,
#     "average_recall": 53.79308213790257
# }
# [1/300] train loss: 1.500 : 100%|█████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.51s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.77it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.69it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.59it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 37.481409311294556,
#     "dress_recall_at50": 63.063955307006836,
#     "toptee_recall_at10": 45.588985085487366,
#     "toptee_recall_at50": 70.32126188278198,
#     "shirt_recall_at10": 43.03238391876221,
#     "shirt_recall_at50": 64.22963738441467,
#     "average_recall_at10": 42.03425943851471,
#     "average_recall_at50": 65.87161819140117,
#     "average_recall": 53.95293881495794
# }
# [2/300] train loss: 1.444 : 100%|█████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:26<00:00,  7.62s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.80it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.65it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.69it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.37382197380066,
#     "dress_recall_at50": 63.212692737579346,
#     "toptee_recall_at10": 45.588985085487366,
#     "toptee_recall_at50": 69.8113203048706,
#     "shirt_recall_at10": 43.32679212093353,
#     "shirt_recall_at50": 64.37684297561646,
#     "average_recall_at10": 42.42986639340719,
#     "average_recall_at50": 65.80028533935547,
#     "average_recall": 54.11507586638133
# }
# [3/300] train loss: 1.454 : 100%|█████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:26<00:00,  7.60s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.83it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.64it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.66it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.86960744857788,
#     "dress_recall_at50": 63.113534450531006,
#     "toptee_recall_at10": 45.79296410083771,
#     "toptee_recall_at50": 70.52524089813232,
#     "shirt_recall_at10": 43.32679212093353,
#     "shirt_recall_at50": 64.52404260635376,
#     "average_recall_at10": 42.66312122344971,
#     "average_recall_at50": 66.05427265167236,
#     "average_recall": 54.358696937561035
# }
# [4/300] train loss: 1.463 : 100%|█████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:24<00:00,  7.55s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.62it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.63it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.69it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.37382197380066,
#     "dress_recall_at50": 62.915217876434326,
#     "toptee_recall_at10": 45.99694013595581,
#     "toptee_recall_at50": 69.65833902359009,
#     "shirt_recall_at10": 43.22865605354309,
#     "shirt_recall_at50": 64.67124819755554,
#     "average_recall_at10": 42.53313938776652,
#     "average_recall_at50": 65.74826836585999,
#     "average_recall": 54.14070387681325
# }
# [5/300] train loss: 1.453 : 100%|█████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:24<00:00,  7.56s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.85it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.66it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.60it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.62171471118927,
#     "dress_recall_at50": 63.361430168151855,
#     "toptee_recall_at10": 45.843955874443054,
#     "toptee_recall_at50": 70.16828060150146,
#     "shirt_recall_at10": 43.57213079929352,
#     "shirt_recall_at50": 64.57310914993286,
#     "average_recall_at10": 42.67926712830862,
#     "average_recall_at50": 66.03427330652873,
#     "average_recall": 54.35677021741867
# }
# [6/300] train loss: 1.446 : 100%|█████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.49s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.74it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.66it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.67it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.77045214176178,
#     "dress_recall_at50": 63.361430168151855,
#     "toptee_recall_at10": 45.99694013595581,
#     "toptee_recall_at50": 70.11728882789612,
#     "shirt_recall_at10": 43.67026388645172,
#     "shirt_recall_at50": 64.81844782829285,
#     "average_recall_at10": 42.812552054723106,
#     "average_recall_at50": 66.0990556081136,
#     "average_recall": 54.45580383141835
# }
# [7/300] train loss: 1.422 : 100%|█████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.52s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.77it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.65it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.64it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.77045214176178,
#     "dress_recall_at50": 63.311851024627686,
#     "toptee_recall_at10": 45.69097459316254,
#     "toptee_recall_at50": 70.21927833557129,
#     "shirt_recall_at10": 43.32679212093353,
#     "shirt_recall_at50": 64.76938128471375,
#     "average_recall_at10": 42.596072951952614,
#     "average_recall_at50": 66.1001702149709,
#     "average_recall": 54.34812158346176
# }
# [8/300] train loss: 1.417 : 100%|█████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.54s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.79it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.55it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.66it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.67129385471344,
#     "dress_recall_at50": 63.262271881103516,
#     "toptee_recall_at10": 45.74196934700012,
#     "toptee_recall_at50": 70.32126188278198,
#     "shirt_recall_at10": 43.32679212093353,
#     "shirt_recall_at50": 64.72031474113464,
#     "average_recall_at10": 42.58001844088236,
#     "average_recall_at50": 66.10128283500671,
#     "average_recall": 54.340650637944535
# }
# [9/300] train loss: 1.436 : 100%|█████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:25<00:00,  7.59s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.83it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.68it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.69it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.52255940437317,
#     "dress_recall_at50": 63.113534450531006,
#     "toptee_recall_at10": 45.89495062828064,
#     "toptee_recall_at50": 70.0662910938263,
#     "shirt_recall_at10": 43.8174694776535,
#     "shirt_recall_at50": 64.72031474113464,
#     "average_recall_at10": 42.74499317010244,
#     "average_recall_at50": 65.96671342849731,
#     "average_recall": 54.35585329929988
# }
# [10/300] train loss: 1.412 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:24<00:00,  7.57s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.77it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.67it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.69it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.62171471118927,
#     "dress_recall_at50": 63.163113594055176,
#     "toptee_recall_at10": 46.404895186424255,
#     "toptee_recall_at50": 70.16828060150146,
#     "shirt_recall_at10": 43.866536021232605,
#     "shirt_recall_at50": 64.76938128471375,
#     "average_recall_at10": 42.96438197294871,
#     "average_recall_at50": 66.03359182675679,
#     "average_recall": 54.49898689985275
# }
# [11/300] train loss: 1.405 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.52s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.72it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.70it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.68it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.5721355676651,
#     "dress_recall_at50": 63.262271881103516,
#     "toptee_recall_at10": 45.79296410083771,
#     "toptee_recall_at50": 69.96430158615112,
#     "shirt_recall_at10": 43.866536021232605,
#     "shirt_recall_at50": 64.62217569351196,
#     "average_recall_at10": 42.74387856324514,
#     "average_recall_at50": 65.94958305358887,
#     "average_recall": 54.34673080841701
# }
# [12/300] train loss: 1.412 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:21<00:00,  7.47s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.75it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.70it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.47it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.86960744857788,
#     "dress_recall_at50": 63.46058249473572,
#     "toptee_recall_at10": 46.302905678749084,
#     "toptee_recall_at50": 69.91330981254578,
#     "shirt_recall_at10": 43.76839995384216,
#     "shirt_recall_at50": 64.57310914993286,
#     "average_recall_at10": 42.98030436038971,
#     "average_recall_at50": 65.98233381907146,
#     "average_recall": 54.48131908973058
# }
# [13/300] train loss: 1.395 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.54s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.79it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.63it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.51it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.67129385471344,
#     "dress_recall_at50": 63.311851024627686,
#     "toptee_recall_at10": 45.63997983932495,
#     "toptee_recall_at50": 70.6272304058075,
#     "shirt_recall_at10": 43.67026388645172,
#     "shirt_recall_at50": 64.81844782829285,
#     "average_recall_at10": 42.66051252683004,
#     "average_recall_at50": 66.25250975290935,
#     "average_recall": 54.45651113986969
# }
# [14/300] train loss: 1.390 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.49s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.67it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.65it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.65it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 39.06792402267456,
#     "dress_recall_at50": 63.311851024627686,
#     "toptee_recall_at10": 45.99694013595581,
#     "toptee_recall_at50": 70.67822813987732,
#     "shirt_recall_at10": 44.21001076698303,
#     "shirt_recall_at50": 64.72031474113464,
#     "average_recall_at10": 43.09162497520447,
#     "average_recall_at50": 66.23679796854655,
#     "average_recall": 54.66421147187551
# }
# [15/300] train loss: 1.381 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.51s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.74it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.60it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.60it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 39.16707932949066,
#     "dress_recall_at50": 63.311851024627686,
#     "toptee_recall_at10": 46.09892964363098,
#     "toptee_recall_at50": 70.42325139045715,
#     "shirt_recall_at10": 43.91560256481171,
#     "shirt_recall_at50": 64.67124819755554,
#     "average_recall_at10": 43.06053717931112,
#     "average_recall_at50": 66.13545020421346,
#     "average_recall": 54.597993691762284
# }
# [16/300] train loss: 1.369 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:24<00:00,  7.57s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.82it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.66it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.61it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.67129385471344,
#     "dress_recall_at50": 63.212692737579346,
#     "toptee_recall_at10": 46.2519109249115,
#     "toptee_recall_at50": 70.27027010917664,
#     "shirt_recall_at10": 43.76839995384216,
#     "shirt_recall_at50": 64.86751437187195,
#     "average_recall_at10": 42.897201577822365,
#     "average_recall_at50": 66.11682573954265,
#     "average_recall": 54.50701365868251
# }
# [17/300] train loss: 1.374 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:24<00:00,  7.56s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.81it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.64it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.64it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.82002830505371,
#     "dress_recall_at50": 63.262271881103516,
#     "toptee_recall_at10": 46.09892964363098,
#     "toptee_recall_at50": 70.27027010917664,
#     "shirt_recall_at10": 43.8174694776535,
#     "shirt_recall_at50": 64.81844782829285,
#     "average_recall_at10": 42.91214247544607,
#     "average_recall_at50": 66.116996606191,
#     "average_recall": 54.51456954081853
# }
# [18/300] train loss: 1.351 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.51s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.81it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.63it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.67it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.82002830505371,
#     "dress_recall_at50": 63.60931992530823,
#     "toptee_recall_at10": 46.2519109249115,
#     "toptee_recall_at50": 70.67822813987732,
#     "shirt_recall_at10": 44.01373863220215,
#     "shirt_recall_at50": 64.67124819755554,
#     "average_recall_at10": 43.02855928738912,
#     "average_recall_at50": 66.31959875424702,
#     "average_recall": 54.67407902081807
# }
# [19/300] train loss: 1.351 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.52s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.76it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.71it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.51it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.67129385471344,
#     "dress_recall_at50": 63.361430168151855,
#     "toptee_recall_at10": 46.20091915130615,
#     "toptee_recall_at50": 70.27027010917664,
#     "shirt_recall_at10": 44.21001076698303,
#     "shirt_recall_at50": 64.57310914993286,
#     "average_recall_at10": 43.027407924334206,
#     "average_recall_at50": 66.06826980908711,
#     "average_recall": 54.54783886671066
# }
# [20/300] train loss: 1.359 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:21<00:00,  7.48s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.79it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.68it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.65it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 39.01834487915039,
#     "dress_recall_at50": 63.6588990688324,
#     "toptee_recall_at10": 46.20091915130615,
#     "toptee_recall_at50": 70.27027010917664,
#     "shirt_recall_at10": 43.8174694776535,
#     "shirt_recall_at50": 64.67124819755554,
#     "average_recall_at10": 43.012244502703346,
#     "average_recall_at50": 66.20013912518819,
#     "average_recall": 54.60619181394577
# }
# [21/300] train loss: 1.349 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.51s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 14.20it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:04<00:00, 14.50it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.60it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.72087299823761,
#     "dress_recall_at50": 63.60931992530823,
#     "toptee_recall_at10": 46.6088742017746,
#     "toptee_recall_at50": 70.11728882789612,
#     "shirt_recall_at10": 43.96467208862305,
#     "shirt_recall_at50": 64.62217569351196,
#     "average_recall_at10": 43.09813976287842,
#     "average_recall_at50": 66.11626148223877,
#     "average_recall": 54.607200622558594
# }
# [22/300] train loss: 1.327 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:24<00:00,  7.55s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.80it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.67it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.57it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 39.16707932949066,
#     "dress_recall_at50": 63.60931992530823,
#     "toptee_recall_at10": 46.302905678749084,
#     "toptee_recall_at50": 70.3722596168518,
#     "shirt_recall_at10": 43.67026388645172,
#     "shirt_recall_at50": 64.67124819755554,
#     "average_recall_at10": 43.04674963156382,
#     "average_recall_at50": 66.21760924657185,
#     "average_recall": 54.63217943906784
# }
# [23/300] train loss: 1.313 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.53s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.77it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.68it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.67it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 39.11750018596649,
#     "dress_recall_at50": 63.70847821235657,
#     "toptee_recall_at10": 46.71086072921753,
#     "toptee_recall_at50": 70.11728882789612,
#     "shirt_recall_at10": 44.06280815601349,
#     "shirt_recall_at50": 64.42590951919556,
#     "average_recall_at10": 43.297056357065834,
#     "average_recall_at50": 66.08389218648274,
#     "average_recall": 54.69047427177429
# }
# [24/300] train loss: 1.327 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:24<00:00,  7.55s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.81it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.70it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.69it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.96876573562622,
#     "dress_recall_at50": 63.311851024627686,
#     "toptee_recall_at10": 46.6088742017746,
#     "toptee_recall_at50": 70.21927833557129,
#     "shirt_recall_at10": 44.06280815601349,
#     "shirt_recall_at50": 64.72031474113464,
#     "average_recall_at10": 43.21348269780477,
#     "average_recall_at50": 66.08381470044453,
#     "average_recall": 54.64864869912465
# }
# [25/300] train loss: 1.302 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:26<00:00,  7.61s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.80it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.70it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.64it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 39.11750018596649,
#     "dress_recall_at50": 63.70847821235657,
#     "toptee_recall_at10": 46.8128502368927,
#     "toptee_recall_at50": 70.27027010917664,
#     "shirt_recall_at10": 43.71933341026306,
#     "shirt_recall_at50": 64.32777047157288,
#     "average_recall_at10": 43.21656127770742,
#     "average_recall_at50": 66.10217293103535,
#     "average_recall": 54.659367104371384
# }
# [26/300] train loss: 1.300 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.53s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.81it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.62it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.63it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.72087299823761,
#     "dress_recall_at50": 63.6588990688324,
#     "toptee_recall_at10": 46.6088742017746,
#     "toptee_recall_at50": 70.21927833557129,
#     "shirt_recall_at10": 44.01373863220215,
#     "shirt_recall_at50": 64.52404260635376,
#     "average_recall_at10": 43.114495277404785,
#     "average_recall_at50": 66.13407333691914,
#     "average_recall": 54.624284307161965
# }
# [27/300] train loss: 1.308 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.52s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.77it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.65it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.63it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 39.16707932949066,
#     "dress_recall_at50": 63.6588990688324,
#     "toptee_recall_at10": 46.404895186424255,
#     "toptee_recall_at50": 69.91330981254578,
#     "shirt_recall_at10": 44.06280815601349,
#     "shirt_recall_at50": 64.72031474113464,
#     "average_recall_at10": 43.211594223976135,
#     "average_recall_at50": 66.09750787417094,
#     "average_recall": 54.65455104907354
# }
# [28/300] train loss: 1.279 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:24<00:00,  7.55s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.81it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.72it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.66it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.96876573562622,
#     "dress_recall_at50": 63.46058249473572,
#     "toptee_recall_at10": 46.404895186424255,
#     "toptee_recall_at50": 69.55634951591492,
#     "shirt_recall_at10": 43.8174694776535,
#     "shirt_recall_at50": 64.67124819755554,
#     "average_recall_at10": 43.06371013323466,
#     "average_recall_at50": 65.89606006940205,
#     "average_recall": 54.47988510131836
# }
# [29/300] train loss: 1.276 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.51s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.85it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.54it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.66it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 39.31581676006317,
#     "dress_recall_at50": 63.55974078178406,
#     "toptee_recall_at10": 46.659865975379944,
#     "toptee_recall_at50": 70.27027010917664,
#     "shirt_recall_at10": 44.06280815601349,
#     "shirt_recall_at50": 64.81844782829285,
#     "average_recall_at10": 43.346163630485535,
#     "average_recall_at50": 66.21615290641785,
#     "average_recall": 54.78115826845169
# }
# [30/300] train loss: 1.268 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.51s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.78it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.65it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.58it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.86960744857788,
#     "dress_recall_at50": 63.6588990688324,
#     "toptee_recall_at10": 46.8128502368927,
#     "toptee_recall_at50": 70.16828060150146,
#     "shirt_recall_at10": 43.76839995384216,
#     "shirt_recall_at50": 64.18057084083557,
#     "average_recall_at10": 43.15028587977091,
#     "average_recall_at50": 66.00258350372314,
#     "average_recall": 54.576434691747025
# }
# [31/300] train loss: 1.263 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.52s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.17it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.61it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.64it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 39.06792402267456,
#     "dress_recall_at50": 63.6588990688324,
#     "toptee_recall_at10": 46.659865975379944,
#     "toptee_recall_at50": 70.52524089813232,
#     "shirt_recall_at10": 44.11187469959259,
#     "shirt_recall_at50": 64.67124819755554,
#     "average_recall_at10": 43.279888232549034,
#     "average_recall_at50": 66.28512938817342,
#     "average_recall": 54.78250881036122
# }
# [32/300] train loss: 1.260 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.54s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.64it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.63it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.60it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.91918659210205,
#     "dress_recall_at50": 63.46058249473572,
#     "toptee_recall_at10": 46.35390043258667,
#     "toptee_recall_at50": 70.01529932022095,
#     "shirt_recall_at10": 43.91560256481171,
#     "shirt_recall_at50": 64.62217569351196,
#     "average_recall_at10": 43.06289652983347,
#     "average_recall_at50": 66.0326858361562,
#     "average_recall": 54.54779118299484
# }
# [33/300] train loss: 1.239 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.53s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.75it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.74it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.38it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 39.31581676006317,
#     "dress_recall_at50": 63.55974078178406,
#     "toptee_recall_at10": 46.14992439746857,
#     "toptee_recall_at50": 70.78021168708801,
#     "shirt_recall_at10": 43.96467208862305,
#     "shirt_recall_at50": 64.72031474113464,
#     "average_recall_at10": 43.1434710820516,
#     "average_recall_at50": 66.35342240333557,
#     "average_recall": 54.74844674269359
# }
# [34/300] train loss: 1.227 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:25<00:00,  7.57s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.81it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.67it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.63it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 39.16707932949066,
#     "dress_recall_at50": 63.46058249473572,
#     "toptee_recall_at10": 46.55787944793701,
#     "toptee_recall_at50": 70.16828060150146,
#     "shirt_recall_at10": 43.67026388645172,
#     "shirt_recall_at50": 64.76938128471375,
#     "average_recall_at10": 43.1317408879598,
#     "average_recall_at50": 66.13274812698364,
#     "average_recall": 54.632244507471725
# }
# [35/300] train loss: 1.223 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.53s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.76it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.66it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.66it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.72087299823761,
#     "dress_recall_at50": 63.75805735588074,
#     "toptee_recall_at10": 46.55787944793701,
#     "toptee_recall_at50": 70.27027010917664,
#     "shirt_recall_at10": 43.91560256481171,
#     "shirt_recall_at50": 65.06378650665283,
#     "average_recall_at10": 43.06478500366211,
#     "average_recall_at50": 66.36403799057007,
#     "average_recall": 54.71441149711609
# }
# [36/300] train loss: 1.201 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.52s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.79it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.57it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 14.99it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.91918659210205,
#     "dress_recall_at50": 63.90679478645325,
#     "toptee_recall_at10": 46.506884694099426,
#     "toptee_recall_at50": 70.42325139045715,
#     "shirt_recall_at10": 43.96467208862305,
#     "shirt_recall_at50": 64.86751437187195,
#     "average_recall_at10": 43.13024779160818,
#     "average_recall_at50": 66.39918684959412,
#     "average_recall": 54.76471732060115
# }
# [37/300] train loss: 1.217 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:24<00:00,  7.56s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.82it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.69it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.63it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 39.01834487915039,
#     "dress_recall_at50": 64.10510540008545,
#     "toptee_recall_at10": 46.302905678749084,
#     "toptee_recall_at50": 70.72921991348267,
#     "shirt_recall_at10": 43.8174694776535,
#     "shirt_recall_at50": 64.42590951919556,
#     "average_recall_at10": 43.04624001185099,
#     "average_recall_at50": 66.42007827758789,
#     "average_recall": 54.73315914471944
# }
# [38/300] train loss: 1.205 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.49s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.77it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.70it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.68it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.91918659210205,
#     "dress_recall_at50": 64.25384283065796,
#     "toptee_recall_at10": 46.45588994026184,
#     "toptee_recall_at50": 70.27027010917664,
#     "shirt_recall_at10": 44.16094124317169,
#     "shirt_recall_at50": 64.91658687591553,
#     "average_recall_at10": 43.17867259184519,
#     "average_recall_at50": 66.4802332719167,
#     "average_recall": 54.82945293188095
# }
# [39/300] train loss: 1.180 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.52s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.79it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.57it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.63it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 39.31581676006317,
#     "dress_recall_at50": 63.75805735588074,
#     "toptee_recall_at10": 46.55787944793701,
#     "toptee_recall_at50": 70.3722596168518,
#     "shirt_recall_at10": 44.01373863220215,
#     "shirt_recall_at50": 64.81844782829285,
#     "average_recall_at10": 43.29581161340078,
#     "average_recall_at50": 66.31625493367513,
#     "average_recall": 54.80603327353795
# }
# [40/300] train loss: 1.191 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.54s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.76it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.65it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.52it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.472980260849,
#     "dress_recall_at50": 63.75805735588074,
#     "toptee_recall_at10": 46.14992439746857,
#     "toptee_recall_at50": 70.3722596168518,
#     "shirt_recall_at10": 44.357213377952576,
#     "shirt_recall_at50": 64.91658687591553,
#     "average_recall_at10": 42.993372678756714,
#     "average_recall_at50": 66.34896794954936,
#     "average_recall": 54.67117031415304
# }
# [41/300] train loss: 1.177 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.52s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.78it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.71it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.59it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.67129385471344,
#     "dress_recall_at50": 64.05552625656128,
#     "toptee_recall_at10": 46.20091915130615,
#     "toptee_recall_at50": 70.6272304058075,
#     "shirt_recall_at10": 43.91560256481171,
#     "shirt_recall_at50": 64.62217569351196,
#     "average_recall_at10": 42.929271856943764,
#     "average_recall_at50": 66.43497745196025,
#     "average_recall": 54.68212465445201
# }
# [42/300] train loss: 1.181 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.52s/it]
# Compute FashionIQ ['dress'] validation predictions
# ...
#     "shirt_recall_at10": 43.375858664512634,
#     "shirt_recall_at50": 64.18057084083557,
#     "average_recall_at10": 42.48021841049194,
#     "average_recall_at50": 65.78302383422852,
#     "average_recall": 54.13162112236023
# }
# [82/300] train loss: 0.890 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.53s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.72it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.57it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.40it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.17550837993622,
#     "dress_recall_at50": 63.80763649940491,
#     "toptee_recall_at10": 45.588985085487366,
#     "toptee_recall_at50": 70.01529932022095,
#     "shirt_recall_at10": 43.22865605354309,
#     "shirt_recall_at50": 63.788026571273804,
#     "average_recall_at10": 42.331049839655556,
#     "average_recall_at50": 65.87032079696655,
#     "average_recall": 54.10068531831105
# }
# [83/300] train loss: 0.892 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.51s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.73it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.62it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.57it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 37.87803649902344,
#     "dress_recall_at50": 63.60931992530823,
#     "toptee_recall_at10": 45.89495062828064,
#     "toptee_recall_at50": 69.60734128952026,
#     "shirt_recall_at10": 42.885181307792664,
#     "shirt_recall_at50": 64.03336524963379,
#     "average_recall_at10": 42.21938947836558,
#     "average_recall_at50": 65.75000882148743,
#     "average_recall": 53.9846991499265
# }
# [84/300] train loss: 0.881 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.49s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 14.25it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:04<00:00, 15.08it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.57it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 37.72930204868317,
#     "dress_recall_at50": 63.55974078178406,
#     "toptee_recall_at10": 45.99694013595581,
#     "toptee_recall_at50": 69.91330981254578,
#     "shirt_recall_at10": 43.08145344257355,
#     "shirt_recall_at50": 64.13150429725647,
#     "average_recall_at10": 42.26923187573751,
#     "average_recall_at50": 65.8681849638621,
#     "average_recall": 54.068708419799805
# }
# [85/300] train loss: 0.863 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.50s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.74it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.60it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.46it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 37.332671880722046,
#     "dress_recall_at50": 62.865644693374634,
#     "toptee_recall_at10": 45.89495062828064,
#     "toptee_recall_at50": 69.50535178184509,
#     "shirt_recall_at10": 42.73797869682312,
#     "shirt_recall_at50": 63.54268789291382,
#     "average_recall_at10": 41.98853373527527,
#     "average_recall_at50": 65.30456145604451,
#     "average_recall": 53.64654759565989
# }
# [86/300] train loss: 0.876 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:24<00:00,  7.55s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.74it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.65it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.49it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 37.679722905159,
#     "dress_recall_at50": 62.964797019958496,
#     "toptee_recall_at10": 45.53799033164978,
#     "toptee_recall_at50": 69.91330981254578,
#     "shirt_recall_at10": 42.78704524040222,
#     "shirt_recall_at50": 63.6898934841156,
#     "average_recall_at10": 42.001586159070335,
#     "average_recall_at50": 65.52266677220662,
#     "average_recall": 53.762126465638474
# }
# [87/300] train loss: 0.858 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.49s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.70it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.58it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.63it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 37.63014376163483,
#     "dress_recall_at50": 63.212692737579346,
#     "toptee_recall_at10": 45.843955874443054,
#     "toptee_recall_at50": 69.55634951591492,
#     "shirt_recall_at10": 42.63984262943268,
#     "shirt_recall_at50": 63.59175443649292,
#     "average_recall_at10": 42.03798075517019,
#     "average_recall_at50": 65.4535988966624,
#     "average_recall": 53.74578982591629
# }
# [88/300] train loss: 0.873 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.52s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.71it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:04<00:00, 15.44it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.58it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 37.183937430381775,
#     "dress_recall_at50": 62.32028007507324,
#     "toptee_recall_at10": 45.945945382118225,
#     "toptee_recall_at50": 69.35237050056458,
#     "shirt_recall_at10": 42.39450395107269,
#     "shirt_recall_at50": 63.6898934841156,
#     "average_recall_at10": 41.84146225452423,
#     "average_recall_at50": 65.1208480199178,
#     "average_recall": 53.481155137221016
# }
# [89/300] train loss: 0.859 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.49s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.75it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.53it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.51it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 37.92761564254761,
#     "dress_recall_at50": 63.361430168151855,
#     "toptee_recall_at10": 45.89495062828064,
#     "toptee_recall_at50": 69.30137872695923,
#     "shirt_recall_at10": 42.83611476421356,
#     "shirt_recall_at50": 63.837093114852905,
#     "average_recall_at10": 42.21956034501394,
#     "average_recall_at50": 65.49996733665466,
#     "average_recall": 53.859763840834304
# }
# [90/300] train loss: 0.847 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.52s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.64it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.63it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.55it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 37.53098547458649,
#     "dress_recall_at50": 62.716907262802124,
#     "toptee_recall_at10": 45.843955874443054,
#     "toptee_recall_at50": 69.60734128952026,
#     "shirt_recall_at10": 43.424925208091736,
#     "shirt_recall_at50": 63.7389600276947,
#     "average_recall_at10": 42.26662218570709,
#     "average_recall_at50": 65.35440286000569,
#     "average_recall": 53.81051252285639
# }
# [91/300] train loss: 0.837 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.50s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 14.46it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:04<00:00, 14.90it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.51it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 37.382251024246216,
#     "dress_recall_at50": 63.113534450531006,
#     "toptee_recall_at10": 45.486995577812195,
#     "toptee_recall_at50": 69.30137872695923,
#     "shirt_recall_at10": 42.73797869682312,
#     "shirt_recall_at50": 63.54268789291382,
#     "average_recall_at10": 41.869075099627175,
#     "average_recall_at50": 65.31920035680135,
#     "average_recall": 53.594137728214264
# }
# [92/300] train loss: 0.830 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:24<00:00,  7.56s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.71it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.63it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.45it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 37.283092737197876,
#     "dress_recall_at50": 62.865644693374634,
#     "toptee_recall_at10": 45.945945382118225,
#     "toptee_recall_at50": 69.35237050056458,
#     "shirt_recall_at10": 42.983317375183105,
#     "shirt_recall_at50": 63.886165618896484,
#     "average_recall_at10": 42.07078516483307,
#     "average_recall_at50": 65.36806027094524,
#     "average_recall": 53.71942271788915
# }
# [93/300] train loss: 0.817 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.54s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.65it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.55it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.56it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 37.382251024246216,
#     "dress_recall_at50": 63.212692737579346,
#     "toptee_recall_at10": 45.843955874443054,
#     "toptee_recall_at50": 69.70933079719543,
#     "shirt_recall_at10": 43.52306127548218,
#     "shirt_recall_at50": 63.935232162475586,
#     "average_recall_at10": 42.24975605805715,
#     "average_recall_at50": 65.6190852324168,
#     "average_recall": 53.93442064523697
# }
# [94/300] train loss: 0.826 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.49s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.63it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.59it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.62it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 37.382251024246216,
#     "dress_recall_at50": 62.816065549850464,
#     "toptee_recall_at10": 45.79296410083771,
#     "toptee_recall_at50": 69.55634951591492,
#     "shirt_recall_at10": 43.03238391876221,
#     "shirt_recall_at50": 63.837093114852905,
#     "average_recall_at10": 42.06919968128204,
#     "average_recall_at50": 65.40316939353943,
#     "average_recall": 53.736184537410736
# }
# [95/300] train loss: 0.822 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:24<00:00,  7.56s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.70it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.50it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.54it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 37.58056461811066,
#     "dress_recall_at50": 62.469011545181274,
#     "toptee_recall_at10": 45.53799033164978,
#     "toptee_recall_at50": 69.55634951591492,
#     "shirt_recall_at10": 42.83611476421356,
#     "shirt_recall_at50": 63.788026571273804,
#     "average_recall_at10": 41.984889904658,
#     "average_recall_at50": 65.27112921079,
#     "average_recall": 53.628009557724
# }
# [96/300] train loss: 0.816 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.52s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.67it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
#   0%|                                                    | 0/62 [00:00<?, ?it/s]
