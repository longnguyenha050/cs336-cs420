# %%
# !git clone https://github.com/ABaldrati/CLIP4Cir
# Out:
# Cloning into 'CLIP4Cir'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 53 (delta 14), reused 6 (delta 6), pack-reused 31 (from 1)
# Receiving objects: 100% (53/53), 1.52 MiB | 31.77 MiB/s, done.
# Resolving deltas: 100% (18/18), done.

# %%
# !pip install comet-ml==3.21.0
# !pip install git+https://github.com/openai/CLIP.git
# !pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 -f 'https://download.pytorch.org/whl/torch_stable.html'
# !pip install pandas==1.4.2
# !pip install urllib3==1.26.15
# !pip install -U comet-ml
# Out:
# Collecting comet-ml==3.21.0
#   Downloading comet_ml-3.21.0-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: websocket-client>=0.55.0 in /usr/local/lib/python3.10/dist-packages (from comet-ml==3.21.0) (1.8.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from comet-ml==3.21.0) (2.32.3)
# Collecting requests-toolbelt>=0.8.0 (from comet-ml==3.21.0)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from comet-ml==3.21.0) (1.16.0)
# Requirement already satisfied: wurlitzer>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from comet-ml==3.21.0) (3.1.1)
# Collecting nvidia-ml-py3>=7.352.0 (from comet-ml==3.21.0)
#   Downloading nvidia-ml-py3-7.352.0.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from comet-ml==3.21.0) (4.23.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.10/dist-packages (from comet-ml==3.21.0) (1.16.0)
# Collecting semantic-version>=2.8.0 (from comet-ml==3.21.0)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting everett>=1.0.1 (from everett[ini]>=1.0.1; python_version > "3.5"->comet-ml==3.21.0)
#   Downloading everett-3.4.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting dulwich>=0.20.6 (from comet-ml==3.21.0)
#   Downloading dulwich-0.22.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.10/dist-packages (from dulwich>=0.20.6->comet-ml==3.21.0) (2.2.3)
# Collecting configobj (from everett[ini]>=1.0.1; python_version > "3.5"->comet-ml==3.21.0)
#   Downloading configobj-5.0.9-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml==3.21.0) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml==3.21.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml==3.21.0) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml==3.21.0) (0.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet-ml==3.21.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet-ml==3.21.0) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet-ml==3.21.0) (2024.8.30)
# Downloading comet_ml-3.21.0-py2.py3-none-any.whl (304 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.9/304.9 kB 20.6 MB/s eta 0:00:00
# Downloading dulwich-0.22.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (980 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 980.3/980.3 kB 46.8 MB/s eta 0:00:00
# Downloading everett-3.4.0-py3-none-any.whl (34 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.6 MB/s eta 0:00:00
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading configobj-5.0.9-py2.py3-none-any.whl (35 kB)
# Building wheels for collected packages: nvidia-ml-py3
#   Building wheel for nvidia-ml-py3 (setup.py) ... done
#   Created wheel for nvidia-ml-py3: filename=nvidia_ml_py3-7.352.0-py3-none-any.whl size=19171 sha256=5c8e6f70bc2d2ac57eb5496239205fe90dea34219888e712dc7c93ca7a25ecc3
#   Stored in directory: /root/.cache/pip/wheels/5c/d8/c0/46899f8be7a75a2ffd197a23c8797700ea858b9b34819fbf9e
# Successfully built nvidia-ml-py3
# Installing collected packages: nvidia-ml-py3, semantic-version, everett, dulwich, configobj, requests-toolbelt, comet-ml
# Successfully installed comet-ml-3.21.0 configobj-5.0.9 dulwich-0.22.7 everett-3.4.0 nvidia-ml-py3-7.352.0 requests-toolbelt-1.0.0 semantic-version-2.10.0
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-gxyx_a11
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-gxyx_a11
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# Collecting ftfy (from clip==1.0)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (24.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (4.66.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (2.4.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (0.19.1+cu121)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from ftfy->clip==1.0) (0.2.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (2024.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->clip==1.0) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->clip==1.0) (1.3.0)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.6 MB/s eta 0:00:00
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369490 sha256=564898a86d1b7802ef94dda5a7280c40e740a1fb8804c9e92f09af77c8a35524
#   Stored in directory: /tmp/pip-ephem-wheel-cache-11l0t26c/wheels/da/2b/4c/d6691fa9597aac8bb85d2ac13b112deb897d5b50f5ad9a37e4
# Successfully built clip
# Installing collected packages: ftfy, clip
# Successfully installed clip-1.0 ftfy-6.3.1
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.11.0+cu113
#   Downloading https://download.pytorch.org/whl/cu113/torch-1.11.0%2Bcu113-cp310-cp310-linux_x86_64.whl (1637.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 GB 899.0 kB/s eta 0:00:000:0100:03
# Collecting torchvision==0.12.0+cu113
#   Downloading https://download.pytorch.org/whl/cu113/torchvision-0.12.0%2Bcu113-cp310-cp310-linux_x86_64.whl (22.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 81.9 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.11.0+cu113) (4.12.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.12.0+cu113) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.12.0+cu113) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.12.0+cu113) (10.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0+cu113) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0+cu113) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0+cu113) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.12.0+cu113) (2024.8.30)
# Installing collected packages: torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.1+cu121
#     Uninstalling torch-2.4.1+cu121:
#       Successfully uninstalled torch-2.4.1+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.19.1+cu121
#     Uninstalling torchvision-0.19.1+cu121:
#       Successfully uninstalled torchvision-0.19.1+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytorch-lightning 2.4.0 requires torch>=2.1.0, but you have torch 1.11.0+cu113 which is incompatible.
# stable-baselines3 2.1.0 requires torch>=1.13, but you have torch 1.11.0+cu113 which is incompatible.
# torchaudio 2.4.1+cu121 requires torch==2.4.1, but you have torch 1.11.0+cu113 which is incompatible.
# torchmetrics 1.6.0 requires torch>=2.0.0, but you have torch 1.11.0+cu113 which is incompatible.
# Successfully installed torch-1.11.0+cu113 torchvision-0.12.0+cu113
# Collecting pandas==1.4.2
#   Downloading pandas-1.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas==1.4.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==1.4.2) (2024.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas==1.4.2) (1.26.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas==1.4.2) (1.16.0)
# Downloading pandas-1.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 108.5 MB/s eta 0:00:0000:010:01
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Uninstalling pandas-2.1.4:
#       Successfully uninstalled pandas-2.1.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# arviz 0.19.0 requires pandas>=1.5.0, but you have pandas 1.4.2 which is incompatible.
# bigframes 1.17.0 requires pandas>=1.5.3, but you have pandas 1.4.2 which is incompatible.
# cudf-cu12 24.4.1 requires pandas<2.2.2dev0,>=2.0, but you have pandas 1.4.2 which is incompatible.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 18.1.0 which is incompatible.
# dask-expr 1.1.21 requires pandas>=2, but you have pandas 1.4.2 which is incompatible.
# featuretools 1.31.0 requires pandas>=2.0.0, but you have pandas 1.4.2 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.5, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.1.4, but you have pandas 1.4.2 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 18.1.0 which is incompatible.
# mizani 0.11.4 requires pandas>=2.1.0, but you have pandas 1.4.2 which is incompatible.
# pandas-gbq 0.23.1 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# plotnine 0.13.6 requires pandas<3.0.0,>=2.1.0, but you have pandas 1.4.2 which is incompatible.
# pyldavis 3.4.1 requires pandas>=2.0.0, but you have pandas 1.4.2 which is incompatible.
# stable-baselines3 2.1.0 requires torch>=1.13, but you have torch 1.11.0+cu113 which is incompatible.
# visions 0.7.6 requires pandas>=2.0.0, but you have pandas 1.4.2 which is incompatible.
# woodwork 0.31.0 requires pandas>=2.0.0, but you have pandas 1.4.2 which is incompatible.
# xarray 2024.9.0 requires pandas>=2.1, but you have pandas 1.4.2 which is incompatible.
# Successfully installed pandas-1.4.2
# Collecting urllib3==1.26.15
#   Downloading urllib3-1.26.15-py2.py3-none-any.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 2.7 MB/s eta 0:00:00
# Downloading urllib3-1.26.15-py2.py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.9/140.9 kB 8.6 MB/s eta 0:00:00
# Installing collected packages: urllib3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.3
#     Uninstalling urllib3-2.2.3:
#       Successfully uninstalled urllib3-2.2.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# distributed 2024.8.0 requires dask==2024.8.0, but you have dask 2024.12.1 which is incompatible.
# Successfully installed urllib3-1.26.15
# Requirement already satisfied: comet-ml in /usr/local/lib/python3.10/dist-packages (3.21.0)
# Collecting comet-ml
#   Downloading comet_ml-3.47.6-py3-none-any.whl.metadata (3.9 kB)
# Collecting everett<3.2.0,>=1.0.1 (from everett[ini]<3.2.0,>=1.0.1->comet-ml)
#   Downloading everett-3.1.0-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (4.23.0)
# Requirement already satisfied: psutil>=5.6.3 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (5.9.5)
# Collecting python-box<7.0.0 (from comet-ml)
#   Downloading python_box-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.8 kB)
# Requirement already satisfied: requests-toolbelt>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (1.0.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (2.32.3)
# Requirement already satisfied: semantic-version>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (2.10.0)
# Requirement already satisfied: sentry-sdk>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (2.19.2)
# Collecting simplejson (from comet-ml)
#   Downloading simplejson-3.19.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (1.26.15)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (1.16.0)
# Requirement already satisfied: wurlitzer>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (3.1.1)
# Requirement already satisfied: dulwich!=0.20.33,>=0.20.6 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (0.22.7)
# Requirement already satisfied: rich>=13.3.2 in /usr/local/lib/python3.10/dist-packages (from comet-ml) (13.8.1)
# Requirement already satisfied: configobj in /usr/local/lib/python3.10/dist-packages (from everett[ini]<3.2.0,>=1.0.1->comet-ml) (5.0.9)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml) (0.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet-ml) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet-ml) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->comet-ml) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet-ml) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13.3.2->comet-ml) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=13.3.2->comet-ml) (0.1.2)
# Downloading comet_ml-3.47.6-py3-none-any.whl (710 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 710.6/710.6 kB 35.6 MB/s eta 0:00:00
# Downloading everett-3.1.0-py2.py3-none-any.whl (35 kB)
# Downloading python_box-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 53.2 MB/s eta 0:00:00a 0:00:01
# Downloading simplejson-3.19.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 10.4 MB/s eta 0:00:00
# Installing collected packages: everett, simplejson, python-box, comet-ml
#   Attempting uninstall: everett
#     Found existing installation: everett 3.4.0
#     Uninstalling everett-3.4.0:
#       Successfully uninstalled everett-3.4.0
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.2.0
#     Uninstalling python-box-7.2.0:
#       Successfully uninstalled python-box-7.2.0
#   Attempting uninstall: comet-ml
#     Found existing installation: comet-ml 3.21.0
#     Uninstalling comet-ml-3.21.0:
#       Successfully uninstalled comet-ml-3.21.0
# Successfully installed comet-ml-3.47.6 everett-3.1.0 python-box-6.1.0 simplejson-3.19.3

# %%
import shutil
import os

# Define source and destination directories
source_dir = '/kaggle/input/fashioniq2'
destination_dir = '/kaggle/working/CLIP4Cir'

# Define the specific source directories for each folder
directories_to_copy = {
    'captions': 'captions-20220326T130604Z-001',
    'image_splits': 'image_splits-20220326T130551Z-001',
    'images': 'images'
}

# Loop through each directory and copy it
for folder_name, src_subdir in directories_to_copy.items():
    src_path = os.path.join(source_dir, src_subdir)
    dest_path = os.path.join(destination_dir, folder_name)
    
    # Ensure the destination directory exists
    os.makedirs(dest_path, exist_ok=True)
    
    # Copy the directory content recursively
    shutil.copytree(src_path, dest_path, dirs_exist_ok=True)

print("Directories copied successfully.")
# Out:
# Directories copied successfully.

# %%
import os
import shutil

# Define source and destination directories
source_dir = '/kaggle/working/CLIP4Cir'
destination_dir = os.path.join(source_dir, 'fashionIQ_dataset')

# Create FashionIQ_dataset directory if it does not exist
os.makedirs(destination_dir, exist_ok=True)

# Define the directories to move
directories_to_move = {
    'captions/captions': 'captions',
    'image_splits/image_splits': 'image_splits',
    'images/images': 'images'
}

# Loop through each directory and check if it exists before moving
for src_subdir, dest_subdir in directories_to_move.items():
    src_path = os.path.join(source_dir, src_subdir)
    dest_path = os.path.join(destination_dir, dest_subdir)
    
    # Check if the source directory exists
    if os.path.exists(src_path):
        # Move the directory to the new location
        shutil.move(src_path, dest_path)
        print(f"Moved {src_path} to {dest_path}")
    else:
        print(f"Source directory {src_path} does not exist.")

print("Directories moved successfully.")
# Out:
# Moved /kaggle/working/CLIP4Cir/captions/captions to /kaggle/working/CLIP4Cir/fashionIQ_dataset/captions
# Moved /kaggle/working/CLIP4Cir/image_splits/image_splits to /kaggle/working/CLIP4Cir/fashionIQ_dataset/image_splits
# Moved /kaggle/working/CLIP4Cir/images/images to /kaggle/working/CLIP4Cir/fashionIQ_dataset/images
# Directories moved successfully.

# %%
from PIL import Image
import os

# Define the directory containing the images
images_dir = '/kaggle/working/CLIP4Cir/fashionIQ_dataset/images'

# Loop through all files in the directory
for filename in os.listdir(images_dir):
    if filename.endswith('.png'):  # Check if the file is a PNG image
        png_path = os.path.join(images_dir, filename)
        
        # Open the PNG image
        with Image.open(png_path) as img:
            # Convert the image to RGB (required for saving as JPG)
            rgb_img = img.convert('RGB')
            
            # Define the new file path with JPG extension
            jpg_path = os.path.join(images_dir, filename.replace('.png', '.jpg'))
            
            # Save the image as JPG
            rgb_img.save(jpg_path, 'JPEG')

            # Optionally, delete the original PNG file
            os.remove(png_path)

print("PNG files have been successfully converted to JPG.")
# Out:
# PNG files have been successfully converted to JPG.

# %%
import torch
torch.cuda.empty_cache()

# %%
# !python /kaggle/working/CLIP4Cir/src/combiner_train.py \
   --dataset FashionIQ \
   --api-key bKMwHTWGZ1fqpCdlAWHrPrP1M \
   --workspace longnguyenha050 \
   --experiment-name combiner_training_fashionIQ \
   --projection-dim 2560 \
   --hidden-dim 5120 \
   --num-epochs 300 \
   --clip-model-name RN50x4 \
   --clip-model-path /kaggle/input/clipfinetunepy/fiq_clip_RN50x4_fullft.pt \
   --combiner-lr 2e-5 \
   --batch-size 512 \
   --clip-bs 32 \
   --transform targetpad \
   --target-ratio 1.25 \
   --save-training \
   --save-best \
   --validation-frequency 1
# Out:
# Comet logging ENABLED
# COMET INFO: Experiment is live on comet.com https://www.comet.com/longnguyenha050/fashioniq-combiner-training/c1ef384c81fa4ec8a9b4ef2a45455d60
#
# COMET INFO: Couldn't find a Git repository in '/kaggle/working' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# 100%|███████████████████████████████████████| 402M/402M [04:17<00:00, 1.64MiB/s]
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/transforms.py:332: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(
# Target pad with target_ratio = 1.25 preprocess pipeline is used
# Trying to load the CLIP model
# CLIP model loaded successfully
# FashionIQ val - ['dress'] dataset in relative mode initialized
# FashionIQ val - ['dress'] dataset in classic mode initialized
# extracting fashionIQ ['dress'] - val index features
# 100%|█████████████████████████████████████████| 120/120 [00:24<00:00,  4.91it/s]
# FashionIQ val - ['toptee'] dataset in relative mode initialized
# FashionIQ val - ['toptee'] dataset in classic mode initialized
# extracting fashionIQ ['toptee'] - val index features
# 100%|█████████████████████████████████████████| 168/168 [00:33<00:00,  5.01it/s]
# FashionIQ val - ['shirt'] dataset in relative mode initialized
# FashionIQ val - ['shirt'] dataset in classic mode initialized
# extracting fashionIQ ['shirt'] - val index features
# 100%|█████████████████████████████████████████| 199/199 [00:39<00:00,  5.01it/s]
# FashionIQ train - ['dress', 'toptee', 'shirt'] dataset in relative mode initialized
# Training loop started
# [0/300] train loss: 1.518 : 100%|█████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:29<00:00,  7.71s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.89it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.85it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.80it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 37.63014376163483,
#     "dress_recall_at50": 62.716907262802124,
#     "toptee_recall_at10": 45.232024788856506,
#     "toptee_recall_at50": 69.35237050056458,
#     "shirt_recall_at10": 43.22865605354309,
#     "shirt_recall_at50": 64.42590951919556,
#     "average_recall_at10": 42.030274868011475,
#     "average_recall_at50": 65.49839576085408,
#     "average_recall": 53.76433531443278
# }
# [1/300] train loss: 1.472 : 100%|█████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:20<00:00,  7.44s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:03<00:00, 16.00it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.81it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.63it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.12592923641205,
#     "dress_recall_at50": 62.816065549850464,
#     "toptee_recall_at10": 45.33401429653168,
#     "toptee_recall_at50": 70.16828060150146,
#     "shirt_recall_at10": 42.83611476421356,
#     "shirt_recall_at50": 64.42590951919556,
#     "average_recall_at10": 42.09868609905243,
#     "average_recall_at50": 65.80341855684917,
#     "average_recall": 53.9510523279508
# }
# [2/300] train loss: 1.460 : 100%|█████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:21<00:00,  7.48s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.94it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.91it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.80it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.17550837993622,
#     "dress_recall_at50": 62.915217876434326,
#     "toptee_recall_at10": 45.63997983932495,
#     "toptee_recall_at50": 69.91330981254578,
#     "shirt_recall_at10": 43.32679212093353,
#     "shirt_recall_at50": 64.42590951919556,
#     "average_recall_at10": 42.38076011339823,
#     "average_recall_at50": 65.75147906939189,
#     "average_recall": 54.066119591395065
# }
# [3/300] train loss: 1.457 : 100%|█████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.53s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.89it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.88it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.81it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.42340111732483,
#     "dress_recall_at50": 62.964797019958496,
#     "toptee_recall_at10": 46.14992439746857,
#     "toptee_recall_at50": 70.32126188278198,
#     "shirt_recall_at10": 43.52306127548218,
#     "shirt_recall_at50": 64.47497606277466,
#     "average_recall_at10": 42.69879559675852,
#     "average_recall_at50": 65.92034498850505,
#     "average_recall": 54.30957029263179
# }
# [4/300] train loss: 1.469 : 100%|█████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.53s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.95it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.87it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.66it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.37382197380066,
#     "dress_recall_at50": 63.163113594055176,
#     "toptee_recall_at10": 45.99694013595581,
#     "toptee_recall_at50": 70.27027010917664,
#     "shirt_recall_at10": 43.8174694776535,
#     "shirt_recall_at50": 64.47497606277466,
#     "average_recall_at10": 42.72941052913666,
#     "average_recall_at50": 65.9694532553355,
#     "average_recall": 54.349431892236076
# }
# [5/300] train loss: 1.447 : 100%|█████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.49s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.93it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.84it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.86it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.42340111732483,
#     "dress_recall_at50": 62.964797019958496,
#     "toptee_recall_at10": 45.945945382118225,
#     "toptee_recall_at50": 70.47424912452698,
#     "shirt_recall_at10": 43.866536021232605,
#     "shirt_recall_at50": 64.57310914993286,
#     "average_recall_at10": 42.745294173558555,
#     "average_recall_at50": 66.0040517648061,
#     "average_recall": 54.37467296918233
# }
# [6/300] train loss: 1.439 : 100%|█████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:26<00:00,  7.61s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.93it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.83it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.75it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.86960744857788,
#     "dress_recall_at50": 63.014376163482666,
#     "toptee_recall_at10": 45.588985085487366,
#     "toptee_recall_at50": 70.47424912452698,
#     "shirt_recall_at10": 43.866536021232605,
#     "shirt_recall_at50": 64.47497606277466,
#     "average_recall_at10": 42.77504285176595,
#     "average_recall_at50": 65.9878671169281,
#     "average_recall": 54.38145498434703
# }
# [7/300] train loss: 1.426 : 100%|█████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:25<00:00,  7.57s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 13.71it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:04<00:00, 15.03it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.55it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.32424283027649,
#     "dress_recall_at50": 63.411009311676025,
#     "toptee_recall_at10": 45.588985085487366,
#     "toptee_recall_at50": 70.42325139045715,
#     "shirt_recall_at10": 43.62119734287262,
#     "shirt_recall_at50": 64.32777047157288,
#     "average_recall_at10": 42.51147508621216,
#     "average_recall_at50": 66.05401039123535,
#     "average_recall": 54.282742738723755
# }
# [8/300] train loss: 1.410 : 100%|█████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.51s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.92it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.73it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.57it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.472980260849,
#     "dress_recall_at50": 63.014376163482666,
#     "toptee_recall_at10": 45.843955874443054,
#     "toptee_recall_at50": 70.27027010917664,
#     "shirt_recall_at10": 44.06280815601349,
#     "shirt_recall_at50": 64.22963738441467,
#     "average_recall_at10": 42.793248097101845,
#     "average_recall_at50": 65.83809455235799,
#     "average_recall": 54.31567132472992
# }
# [9/300] train loss: 1.411 : 100%|█████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.51s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.68it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.57it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.58it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.472980260849,
#     "dress_recall_at50": 63.212692737579346,
#     "toptee_recall_at10": 45.99694013595581,
#     "toptee_recall_at50": 70.3722596168518,
#     "shirt_recall_at10": 43.8174694776535,
#     "shirt_recall_at50": 64.62217569351196,
#     "average_recall_at10": 42.76246329148611,
#     "average_recall_at50": 66.0690426826477,
#     "average_recall": 54.41575298706691
# }
# [10/300] train loss: 1.394 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:24<00:00,  7.56s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.85it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.83it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.71it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.67129385471344,
#     "dress_recall_at50": 63.311851024627686,
#     "toptee_recall_at10": 45.99694013595581,
#     "toptee_recall_at50": 70.6272304058075,
#     "shirt_recall_at10": 43.76839995384216,
#     "shirt_recall_at50": 64.37684297561646,
#     "average_recall_at10": 42.812211314837135,
#     "average_recall_at50": 66.10530813535054,
#     "average_recall": 54.45875972509384
# }
# [11/300] train loss: 1.411 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.50s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.63it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.58it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.38it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.62171471118927,
#     "dress_recall_at50": 62.865644693374634,
#     "toptee_recall_at10": 45.843955874443054,
#     "toptee_recall_at50": 70.52524089813232,
#     "shirt_recall_at10": 43.76839995384216,
#     "shirt_recall_at50": 64.81844782829285,
#     "average_recall_at10": 42.74469017982483,
#     "average_recall_at50": 66.06977780659993,
#     "average_recall": 54.40723399321238
# }
# [12/300] train loss: 1.410 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:25<00:00,  7.59s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.93it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.81it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.78it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.42340111732483,
#     "dress_recall_at50": 63.262271881103516,
#     "toptee_recall_at10": 46.14992439746857,
#     "toptee_recall_at50": 70.21927833557129,
#     "shirt_recall_at10": 43.866536021232605,
#     "shirt_recall_at50": 64.67124819755554,
#     "average_recall_at10": 42.81328717867533,
#     "average_recall_at50": 66.05093280474345,
#     "average_recall": 54.432109991709396
# }
# [13/300] train loss: 1.411 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.53s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.54it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.50it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.48it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.72087299823761,
#     "dress_recall_at50": 63.212692737579346,
#     "toptee_recall_at10": 45.89495062828064,
#     "toptee_recall_at50": 70.52524089813232,
#     "shirt_recall_at10": 43.96467208862305,
#     "shirt_recall_at50": 64.57310914993286,
#     "average_recall_at10": 42.86016523838043,
#     "average_recall_at50": 66.10368092854817,
#     "average_recall": 54.4819230834643
# }
# [14/300] train loss: 1.395 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:26<00:00,  7.60s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.74it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.75it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.74it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.72087299823761,
#     "dress_recall_at50": 63.262271881103516,
#     "toptee_recall_at10": 46.35390043258667,
#     "toptee_recall_at50": 70.98419070243835,
#     "shirt_recall_at10": 44.11187469959259,
#     "shirt_recall_at50": 64.47497606277466,
#     "average_recall_at10": 43.06221604347229,
#     "average_recall_at50": 66.24047954877217,
#     "average_recall": 54.65134779612223
# }
# [15/300] train loss: 1.378 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.51s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.88it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.71it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.55it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.42340111732483,
#     "dress_recall_at50": 63.46058249473572,
#     "toptee_recall_at10": 46.302905678749084,
#     "toptee_recall_at50": 70.3722596168518,
#     "shirt_recall_at10": 43.76839995384216,
#     "shirt_recall_at50": 64.47497606277466,
#     "average_recall_at10": 42.831568916638695,
#     "average_recall_at50": 66.10260605812073,
#     "average_recall": 54.467087487379715
# }
# [16/300] train loss: 1.387 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:21<00:00,  7.46s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.87it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.77it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.71it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.5721355676651,
#     "dress_recall_at50": 63.063955307006836,
#     "toptee_recall_at10": 45.99694013595581,
#     "toptee_recall_at50": 70.3722596168518,
#     "shirt_recall_at10": 44.06280815601349,
#     "shirt_recall_at50": 64.72031474113464,
#     "average_recall_at10": 42.877294619878136,
#     "average_recall_at50": 66.05217655499776,
#     "average_recall": 54.46473558743794
# }
# [17/300] train loss: 1.384 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.49s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.83it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.68it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.55it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.62171471118927,
#     "dress_recall_at50": 63.70847821235657,
#     "toptee_recall_at10": 45.99694013595581,
#     "toptee_recall_at50": 70.57623863220215,
#     "shirt_recall_at10": 43.8174694776535,
#     "shirt_recall_at50": 64.47497606277466,
#     "average_recall_at10": 42.812041441599526,
#     "average_recall_at50": 66.25323096911113,
#     "average_recall": 54.53263620535533
# }
# [18/300] train loss: 1.362 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.52s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.90it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.77it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.74it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.27466666698456,
#     "dress_recall_at50": 63.262271881103516,
#     "toptee_recall_at10": 46.302905678749084,
#     "toptee_recall_at50": 70.27027010917664,
#     "shirt_recall_at10": 43.91560256481171,
#     "shirt_recall_at50": 64.81844782829285,
#     "average_recall_at10": 42.831058303515114,
#     "average_recall_at50": 66.116996606191,
#     "average_recall": 54.47402745485306
# }
# [19/300] train loss: 1.379 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:21<00:00,  7.48s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.65it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.62it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.56it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.82002830505371,
#     "dress_recall_at50": 63.163113594055176,
#     "toptee_recall_at10": 46.20091915130615,
#     "toptee_recall_at50": 70.98419070243835,
#     "shirt_recall_at10": 44.16094124317169,
#     "shirt_recall_at50": 64.57310914993286,
#     "average_recall_at10": 43.06062956651052,
#     "average_recall_at50": 66.24013781547546,
#     "average_recall": 54.650383690992996
# }
# [20/300] train loss: 1.341 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.54s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.88it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.68it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.68it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.77045214176178,
#     "dress_recall_at50": 63.411009311676025,
#     "toptee_recall_at10": 46.2519109249115,
#     "toptee_recall_at50": 70.72921991348267,
#     "shirt_recall_at10": 43.8174694776535,
#     "shirt_recall_at50": 64.72031474113464,
#     "average_recall_at10": 42.946610848108925,
#     "average_recall_at50": 66.28684798876445,
#     "average_recall": 54.61672941843669
# }
# [21/300] train loss: 1.329 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:21<00:00,  7.48s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.90it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.73it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.76it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.37382197380066,
#     "dress_recall_at50": 63.46058249473572,
#     "toptee_recall_at10": 46.302905678749084,
#     "toptee_recall_at50": 70.27027010917664,
#     "shirt_recall_at10": 43.96467208862305,
#     "shirt_recall_at50": 64.72031474113464,
#     "average_recall_at10": 42.88046658039093,
#     "average_recall_at50": 66.15038911501567,
#     "average_recall": 54.5154278477033
# }
# [22/300] train loss: 1.351 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:24<00:00,  7.56s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.88it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.79it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.76it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.77045214176178,
#     "dress_recall_at50": 63.55974078178406,
#     "toptee_recall_at10": 46.55787944793701,
#     "toptee_recall_at50": 70.47424912452698,
#     "shirt_recall_at10": 44.11187469959259,
#     "shirt_recall_at50": 65.01471996307373,
#     "average_recall_at10": 43.146735429763794,
#     "average_recall_at50": 66.3495699564616,
#     "average_recall": 54.748152693112694
# }
# [23/300] train loss: 1.341 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.52s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.83it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.77it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.70it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 39.11750018596649,
#     "dress_recall_at50": 63.262271881103516,
#     "toptee_recall_at10": 46.20091915130615,
#     "toptee_recall_at50": 70.72921991348267,
#     "shirt_recall_at10": 43.91560256481171,
#     "shirt_recall_at50": 64.52404260635376,
#     "average_recall_at10": 43.078007300694786,
#     "average_recall_at50": 66.17184480031331,
#     "average_recall": 54.624926050504044
# }
# [24/300] train loss: 1.333 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.51s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 14.34it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:04<00:00, 14.99it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.64it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.72087299823761,
#     "dress_recall_at50": 63.113534450531006,
#     "toptee_recall_at10": 46.20091915130615,
#     "toptee_recall_at50": 70.6272304058075,
#     "shirt_recall_at10": 44.01373863220215,
#     "shirt_recall_at50": 64.32777047157288,
#     "average_recall_at10": 42.97851026058197,
#     "average_recall_at50": 66.02284510930379,
#     "average_recall": 54.50067768494288
# }
# [25/300] train loss: 1.318 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:21<00:00,  7.48s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.76it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.75it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.60it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.82002830505371,
#     "dress_recall_at50": 63.6588990688324,
#     "toptee_recall_at10": 46.506884694099426,
#     "toptee_recall_at50": 70.21927833557129,
#     "shirt_recall_at10": 43.96467208862305,
#     "shirt_recall_at50": 64.76938128471375,
#     "average_recall_at10": 43.09719502925873,
#     "average_recall_at50": 66.21585289637248,
#     "average_recall": 54.656523962815605
# }
# [26/300] train loss: 1.290 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:21<00:00,  7.48s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.89it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.66it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.70it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.77045214176178,
#     "dress_recall_at50": 63.51016163825989,
#     "toptee_recall_at10": 46.302905678749084,
#     "toptee_recall_at50": 70.3722596168518,
#     "shirt_recall_at10": 43.96467208862305,
#     "shirt_recall_at50": 64.72031474113464,
#     "average_recall_at10": 43.01267663637797,
#     "average_recall_at50": 66.20091199874878,
#     "average_recall": 54.60679431756337
# }
# [27/300] train loss: 1.299 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:24<00:00,  7.56s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.89it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.74it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.71it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.91918659210205,
#     "dress_recall_at50": 63.75805735588074,
#     "toptee_recall_at10": 46.2519109249115,
#     "toptee_recall_at50": 70.98419070243835,
#     "shirt_recall_at10": 43.8174694776535,
#     "shirt_recall_at50": 64.52404260635376,
#     "average_recall_at10": 42.99618899822235,
#     "average_recall_at50": 66.42209688822429,
#     "average_recall": 54.70914294322332
# }
# [28/300] train loss: 1.286 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:21<00:00,  7.48s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.87it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.77it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.70it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 39.16707932949066,
#     "dress_recall_at50": 63.51016163825989,
#     "toptee_recall_at10": 46.20091915130615,
#     "toptee_recall_at50": 70.83120942115784,
#     "shirt_recall_at10": 43.57213079929352,
#     "shirt_recall_at50": 64.57310914993286,
#     "average_recall_at10": 42.98004309336344,
#     "average_recall_at50": 66.3048267364502,
#     "average_recall": 54.642434914906815
# }
# [29/300] train loss: 1.280 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.50s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.63it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.82it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.74it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 39.01834487915039,
#     "dress_recall_at50": 63.90679478645325,
#     "toptee_recall_at10": 46.14992439746857,
#     "toptee_recall_at50": 70.67822813987732,
#     "shirt_recall_at10": 43.71933341026306,
#     "shirt_recall_at50": 64.62217569351196,
#     "average_recall_at10": 42.96253422896067,
#     "average_recall_at50": 66.40239953994751,
#     "average_recall": 54.68246688445409
# }
# [30/300] train loss: 1.262 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.50s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.92it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.72it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.74it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.77045214176178,
#     "dress_recall_at50": 63.51016163825989,
#     "toptee_recall_at10": 46.55787944793701,
#     "toptee_recall_at50": 70.78021168708801,
#     "shirt_recall_at10": 43.67026388645172,
#     "shirt_recall_at50": 64.42590951919556,
#     "average_recall_at10": 42.99953182538351,
#     "average_recall_at50": 66.23876094818115,
#     "average_recall": 54.61914638678233
# }
# [31/300] train loss: 1.260 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.50s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 14.42it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:04<00:00, 15.19it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.72it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.86960744857788,
#     "dress_recall_at50": 63.80763649940491,
#     "toptee_recall_at10": 46.14992439746857,
#     "toptee_recall_at50": 70.83120942115784,
#     "shirt_recall_at10": 44.11187469959259,
#     "shirt_recall_at50": 64.81844782829285,
#     "average_recall_at10": 43.04380218187968,
#     "average_recall_at50": 66.48576458295186,
#     "average_recall": 54.76478338241577
# }
# [32/300] train loss: 1.252 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:24<00:00,  7.55s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.80it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.72it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.72it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 39.11750018596649,
#     "dress_recall_at50": 63.75805735588074,
#     "toptee_recall_at10": 46.404895186424255,
#     "toptee_recall_at50": 70.6272304058075,
#     "shirt_recall_at10": 43.71933341026306,
#     "shirt_recall_at50": 64.81844782829285,
#     "average_recall_at10": 43.080576260884605,
#     "average_recall_at50": 66.40124519666035,
#     "average_recall": 54.74091072877248
# }
# [33/300] train loss: 1.230 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:21<00:00,  7.47s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.79it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.69it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.59it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 39.06792402267456,
#     "dress_recall_at50": 63.55974078178406,
#     "toptee_recall_at10": 46.45588994026184,
#     "toptee_recall_at50": 70.78021168708801,
#     "shirt_recall_at10": 43.71933341026306,
#     "shirt_recall_at50": 64.86751437187195,
#     "average_recall_at10": 43.08104912439982,
#     "average_recall_at50": 66.40248894691467,
#     "average_recall": 54.74176903565724
# }
# [34/300] train loss: 1.231 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:20<00:00,  7.45s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.84it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.74it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.74it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 39.01834487915039,
#     "dress_recall_at50": 63.80763649940491,
#     "toptee_recall_at10": 46.506884694099426,
#     "toptee_recall_at50": 70.88220119476318,
#     "shirt_recall_at10": 43.67026388645172,
#     "shirt_recall_at50": 64.52404260635376,
#     "average_recall_at10": 43.06516448656718,
#     "average_recall_at50": 66.40462676684062,
#     "average_recall": 54.7348956267039
# }
# [35/300] train loss: 1.236 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:21<00:00,  7.49s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.79it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.74it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.75it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.52255940437317,
#     "dress_recall_at50": 64.20426368713379,
#     "toptee_recall_at10": 46.2519109249115,
#     "toptee_recall_at50": 70.83120942115784,
#     "shirt_recall_at10": 43.62119734287262,
#     "shirt_recall_at50": 64.47497606277466,
#     "average_recall_at10": 42.79855589071909,
#     "average_recall_at50": 66.5034830570221,
#     "average_recall": 54.65101947387059
# }
# [36/300] train loss: 1.226 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.51s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.85it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.75it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.54it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.22508752346039,
#     "dress_recall_at50": 63.75805735588074,
#     "toptee_recall_at10": 45.99694013595581,
#     "toptee_recall_at50": 70.32126188278198,
#     "shirt_recall_at10": 44.01373863220215,
#     "shirt_recall_at50": 64.52404260635376,
#     "average_recall_at10": 42.74525543053945,
#     "average_recall_at50": 66.2011206150055,
#     "average_recall": 54.473188022772476
# }
# [37/300] train loss: 1.219 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:21<00:00,  7.48s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.84it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.80it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.71it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.52255940437317,
#     "dress_recall_at50": 63.6588990688324,
#     "toptee_recall_at10": 46.404895186424255,
#     "toptee_recall_at50": 70.67822813987732,
#     "shirt_recall_at10": 44.21001076698303,
#     "shirt_recall_at50": 64.91658687591553,
#     "average_recall_at10": 43.04582178592682,
#     "average_recall_at50": 66.41790469487508,
#     "average_recall": 54.73186324040095
# }
# [38/300] train loss: 1.205 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:21<00:00,  7.47s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.93it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.74it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.70it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.5721355676651,
#     "dress_recall_at50": 63.90679478645325,
#     "toptee_recall_at10": 46.8128502368927,
#     "toptee_recall_at50": 70.6272304058075,
#     "shirt_recall_at10": 44.357213377952576,
#     "shirt_recall_at50": 64.91658687591553,
#     "average_recall_at10": 43.247399727503456,
#     "average_recall_at50": 66.48353735605876,
#     "average_recall": 54.86546854178111
# }
# [39/300] train loss: 1.187 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:24<00:00,  7.55s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.81it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.77it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.74it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 39.11750018596649,
#     "dress_recall_at50": 64.20426368713379,
#     "toptee_recall_at10": 46.302905678749084,
#     "toptee_recall_at50": 70.98419070243835,
#     "shirt_recall_at10": 44.259077310562134,
#     "shirt_recall_at50": 64.13150429725647,
#     "average_recall_at10": 43.22649439175924,
#     "average_recall_at50": 66.43998622894287,
#     "average_recall": 54.83324031035106
# }
# [40/300] train loss: 1.167 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.49s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.90it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.67it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.62it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.77045214176178,
#     "dress_recall_at50": 64.05552625656128,
#     "toptee_recall_at10": 46.2519109249115,
#     "toptee_recall_at50": 70.42325139045715,
#     "shirt_recall_at10": 43.866536021232605,
#     "shirt_recall_at50": 64.42590951919556,
#     "average_recall_at10": 42.96296636263529,
#     "average_recall_at50": 66.30156238873799,
#     "average_recall": 54.632264375686646
# }
# [41/300] train loss: 1.169 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.49s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.74it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.79it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.71it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.62171471118927,
#     "dress_recall_at50": 64.25384283065796,
#     "toptee_recall_at10": 46.20091915130615,
#     "toptee_recall_at50": 70.72921991348267,
#     "shirt_recall_at10": 43.866536021232605,
#     "shirt_recall_at50": 64.96565341949463,
#     "average_recall_at10": 42.896389961242676,
#     "average_recall_at50": 66.64957205454509,
#     "average_recall": 54.77298100789388
# }
# [42/300] train loss: 1.151 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.51s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.81it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.74it/s]
# ...
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.53it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.52255940437317,
#     "dress_recall_at50": 63.95636796951294,
#     "toptee_recall_at10": 45.89495062828064,
#     "toptee_recall_at50": 69.91330981254578,
#     "shirt_recall_at10": 43.866536021232605,
#     "shirt_recall_at50": 64.81844782829285,
#     "average_recall_at10": 42.76134868462881,
#     "average_recall_at50": 66.22937520345052,
#     "average_recall": 54.49536194403966
# }
# [53/300] train loss: 1.073 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:21<00:00,  7.47s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.69it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.60it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.54it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 39.06792402267456,
#     "dress_recall_at50": 64.3530011177063,
#     "toptee_recall_at10": 46.047934889793396,
#     "toptee_recall_at50": 69.70933079719543,
#     "shirt_recall_at10": 44.06280815601349,
#     "shirt_recall_at50": 64.57310914993286,
#     "average_recall_at10": 43.05955568949381,
#     "average_recall_at50": 66.2118136882782,
#     "average_recall": 54.635684688886
# }
# [54/300] train loss: 1.063 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.52s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.67it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:04<00:00, 15.41it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.39it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.91918659210205,
#     "dress_recall_at50": 64.30342197418213,
#     "toptee_recall_at10": 46.09892964363098,
#     "toptee_recall_at50": 69.96430158615112,
#     "shirt_recall_at10": 44.50441598892212,
#     "shirt_recall_at50": 64.57310914993286,
#     "average_recall_at10": 43.174177408218384,
#     "average_recall_at50": 66.2802775700887,
#     "average_recall": 54.72722748915354
# }
# [55/300] train loss: 1.064 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:25<00:00,  7.57s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.71it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.62it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.57it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.5721355676651,
#     "dress_recall_at50": 63.80763649940491,
#     "toptee_recall_at10": 46.45588994026184,
#     "toptee_recall_at50": 70.32126188278198,
#     "shirt_recall_at10": 44.700688123703,
#     "shirt_recall_at50": 64.62217569351196,
#     "average_recall_at10": 43.24290454387665,
#     "average_recall_at50": 66.25035802523296,
#     "average_recall": 54.7466312845548
# }
# [56/300] train loss: 1.041 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:21<00:00,  7.47s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.66it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.58it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.59it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.22508752346039,
#     "dress_recall_at50": 63.95636796951294,
#     "toptee_recall_at10": 46.404895186424255,
#     "toptee_recall_at50": 70.27027010917664,
#     "shirt_recall_at10": 44.259077310562134,
#     "shirt_recall_at50": 64.03336524963379,
#     "average_recall_at10": 42.96302000681559,
#     "average_recall_at50": 66.08666777610779,
#     "average_recall": 54.524843891461686
# }
# [57/300] train loss: 1.047 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.51s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 14.32it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:04<00:00, 14.88it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.48it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 39.11750018596649,
#     "dress_recall_at50": 64.15468454360962,
#     "toptee_recall_at10": 46.047934889793396,
#     "toptee_recall_at50": 70.98419070243835,
#     "shirt_recall_at10": 44.11187469959259,
#     "shirt_recall_at50": 64.32777047157288,
#     "average_recall_at10": 43.09243659178416,
#     "average_recall_at50": 66.48888190587361,
#     "average_recall": 54.79065924882889
# }
# [58/300] train loss: 1.050 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:21<00:00,  7.46s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.74it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.58it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.60it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.82002830505371,
#     "dress_recall_at50": 64.10510540008545,
#     "toptee_recall_at10": 45.99694013595581,
#     "toptee_recall_at50": 70.47424912452698,
#     "shirt_recall_at10": 43.96467208862305,
#     "shirt_recall_at50": 64.42590951919556,
#     "average_recall_at10": 42.927213509877525,
#     "average_recall_at50": 66.33508801460266,
#     "average_recall": 54.6311507622401
# }
# [59/300] train loss: 1.033 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.50s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.59it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.61it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.50it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.5721355676651,
#     "dress_recall_at50": 64.30342197418213,
#     "toptee_recall_at10": 45.79296410083771,
#     "toptee_recall_at50": 70.27027010917664,
#     "shirt_recall_at10": 43.76839995384216,
#     "shirt_recall_at50": 64.03336524963379,
#     "average_recall_at10": 42.711166540781655,
#     "average_recall_at50": 66.20235244433086,
#     "average_recall": 54.45675949255626
# }
# [60/300] train loss: 1.016 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:23<00:00,  7.53s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.71it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.62it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.39it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.32424283027649,
#     "dress_recall_at50": 63.6588990688324,
#     "toptee_recall_at10": 45.843955874443054,
#     "toptee_recall_at50": 70.11728882789612,
#     "shirt_recall_at10": 43.76839995384216,
#     "shirt_recall_at50": 64.08243179321289,
#     "average_recall_at10": 42.64553288618723,
#     "average_recall_at50": 65.95287322998047,
#     "average_recall": 54.29920305808385
# }
# [61/300] train loss: 1.019 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:24<00:00,  7.56s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.73it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.54it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.48it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.62171471118927,
#     "dress_recall_at50": 64.15468454360962,
#     "toptee_recall_at10": 46.2519109249115,
#     "toptee_recall_at50": 70.3722596168518,
#     "shirt_recall_at10": 44.06280815601349,
#     "shirt_recall_at50": 63.886165618896484,
#     "average_recall_at10": 42.978811264038086,
#     "average_recall_at50": 66.13770325978597,
#     "average_recall": 54.558257261912026
# }
# [62/300] train loss: 1.029 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:21<00:00,  7.48s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.66it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.53it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.54it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.86960744857788,
#     "dress_recall_at50": 64.50173258781433,
#     "toptee_recall_at10": 46.863844990730286,
#     "toptee_recall_at50": 70.47424912452698,
#     "shirt_recall_at10": 44.45534944534302,
#     "shirt_recall_at50": 63.788026571273804,
#     "average_recall_at10": 43.39626729488373,
#     "average_recall_at50": 66.2546694278717,
#     "average_recall": 54.825468361377716
# }
# [63/300] train loss: 0.999 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:24<00:00,  7.55s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.66it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.55it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.53it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.77045214176178,
#     "dress_recall_at50": 64.60089087486267,
#     "toptee_recall_at10": 46.35390043258667,
#     "toptee_recall_at50": 70.57623863220215,
#     "shirt_recall_at10": 44.16094124317169,
#     "shirt_recall_at50": 64.08243179321289,
#     "average_recall_at10": 43.09509793917338,
#     "average_recall_at50": 66.41985376675923,
#     "average_recall": 54.75747585296631
# }
# [64/300] train loss: 1.002 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:21<00:00,  7.46s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.72it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.57it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.55it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.72087299823761,
#     "dress_recall_at50": 63.75805735588074,
#     "toptee_recall_at10": 46.09892964363098,
#     "toptee_recall_at50": 69.91330981254578,
#     "shirt_recall_at10": 44.21001076698303,
#     "shirt_recall_at50": 64.18057084083557,
#     "average_recall_at10": 43.00993780295054,
#     "average_recall_at50": 65.95064600308736,
#     "average_recall": 54.48029190301895
# }
# [65/300] train loss: 0.993 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:22<00:00,  7.51s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.64it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.55it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.54it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.62171471118927,
#     "dress_recall_at50": 64.05552625656128,
#     "toptee_recall_at10": 46.45588994026184,
#     "toptee_recall_at50": 70.32126188278198,
#     "shirt_recall_at10": 43.67026388645172,
#     "shirt_recall_at50": 64.37684297561646,
#     "average_recall_at10": 42.91595617930094,
#     "average_recall_at50": 66.25121037165324,
#     "average_recall": 54.583583275477096
# }
# [66/300] train loss: 0.981 : 100%|████████████████████████████████████████████████████████████████████████████████████| 35/35 [04:25<00:00,  7.59s/it]
# Compute FashionIQ ['dress'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.60it/s]
# Compute FashionIQ ['dress'] validation metrics
# Compute FashionIQ ['toptee'] validation predictions
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 15.53it/s]
# Compute FashionIQ ['toptee'] validation metrics
# Compute FashionIQ ['shirt'] validation predictions
# 100%|███████████████████████████████████████████| 64/64 [00:04<00:00, 15.48it/s]
# Compute FashionIQ ['shirt'] validation metrics
# {
#     "dress_recall_at10": 38.67129385471344,
#     "dress_recall_at50": 64.50173258781433,
#     "toptee_recall_at10": 46.14992439746857,
#     "toptee_recall_at50": 69.91330981254578,
#     "shirt_recall_at10": 43.424925208091736,
#     "shirt_recall_at50": 64.18057084083557,
#     "average_recall_at10": 42.74871448675791,
#     "average_recall_at50": 66.19853774706523,
#     "average_recall": 54.473626116911575
# }
# [67/300] train loss: 0.984 :  74%|██████████████████████████████████████████████████████████████▍                     | 26/35 [03:22<01:04,  7.12s/it]
